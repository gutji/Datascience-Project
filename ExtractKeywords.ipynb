# %%
import pandas as pd
df = pd.read_csv('merged_data_withkeywords.csv')
df
# Out:
#                                                    title  \
# 0      Effects of iron content on the microstructure ...
# 1      The critical factors of research and innovatio...
# 2      Is the occiput-wall distance valid and reliabl...
# 3      Comparison of soil composition between farmlan...
# 4      The impact of wire caliber on ERCP outcomes: a...
# ...                                                  ...
# 22601  A SOM-Based Trajectory Planning Analysis Metho...
# 22602  Overview and Research on Airworthiness and Saf...
# 22603  Aeroengine Gas Path Parameter Trend Prediction...
# 22604  A Wind Tunnel Investigation on the Aerodynamic...
# 22605  High-Precision Modeling and Online Validation ...
#
#                                          publicationName  \
# 0                        Materials Chemistry and Physics
# 1      International Journal of Trade and Global Markets
# 2                   Musculoskeletal Science and Practice
# 3               Eurasian Journal of Analytical Chemistry
# 4                             Gastrointestinal Endoscopy
# ...                                                  ...
# 22601                               SAE Technical Papers
# 22602                               SAE Technical Papers
# 22603                               SAE Technical Papers
# 22604                               SAE Technical Papers
# 22605                               SAE Technical Papers
#
#                                                 abstract  \
# 0      © 2018The microstructure and corrosion behavio...
# 1      Copyright © 2018 Inderscience Enterprises Ltd....
# 2      © 2018Background: Hyperkyphosis may be frequen...
# 3      © 2018 Society for Innovative Research. All ri...
# 4      © 2018Background and Aims: Wire-guided biliary...
# ...                                                  ...
# 22601                                                NaN
# 22602                                                NaN
# 22603                                                NaN
# 22604                                                NaN
# 22605                                                NaN
#
#                                                 keywords subjectArea  \
# 0      EIS,Microstructure,Pitting corrosion,Polarizat...   MATE,PHYS
# 1      Critical factors,Innovation creation,Public un...   BUSI,ECON
# 2             Cobb angle,Dowager's hump,Round back,Spine        HEAL
# 3      Agriculture land management,Conserved area,Soi...   PHAR,CHEM
# 4                                                    NaN        MEDI
# ...                                                  ...         ...
# 22601                                                NaN        ENGI
# 22602                                                NaN   ENGI,MEDI
# 22603                                                NaN        ENGI
# 22604                                                NaN        ENGI
# 22605                                                NaN        ENGI
#
#       publication_date                                           combined  \
# 0           01/10/2018  Effects of iron content on the microstructure ...
# 1           01/01/2018  The critical factors of research and innovatio...
# 2           01/12/2018  Is the occiput-wall distance valid and reliabl...
# 3           01/01/2018  Comparison of soil composition between farmlan...
# 4           01/06/2018  The impact of wire caliber on ERCP outcomes: a...
# ...                ...                                                ...
# 22601       31/12/2023  A SOM-Based Trajectory Planning Analysis Metho...
# 22602       31/12/2023  Overview and Research on Airworthiness and Saf...
# 22603       31/12/2023  Aeroengine Gas Path Parameter Trend Prediction...
# 22604       31/12/2023  A Wind Tunnel Investigation on the Aerodynamic...
# 22605       31/12/2023  High-Precision Modeling and Online Validation ...
#
#                                                processed  \
# 0      effects iron content microstructure corrosion ...
# 1      critical factors research innovation creation ...
# 2      occiput-wall distance valid reliable determine...
# 3      comparison soil composition farmlands conserve...
# 4      impact wire caliber ercp outcomes multicenter ...
# ...                                                  ...
# 22601  som-based trajectory planning analysis method ...
# 22602  overview research airworthiness safety electri...
# 22603  aeroengine gas path parameter trend prediction...
# 22604  wind tunnel investigation aerodynamics propuls...
# 22605  high-precision modeling online validation 200k...
#
#                        Top_Three_Keywords    One_keyword
# 0              alloys, corrosion, exhibit         alloys
# 1      universities, creation, innovation   universities
# 2            hyperkyphosis, owd, thoracic  hyperkyphosis
# 3             farmlands, soils, conserved      farmlands
# 4                 inch, cannulation, wire           inch
# ...                                   ...            ...
# 22601        som, trajectory, intelligent            som
# 22602    airworthiness, propulsion, evtol  airworthiness
# 22603              aeroengine, lstm, path     aeroengine
# 22604     aerodynamics, propulsion, evtol   aerodynamics
# 22605          200kw, aviation, precision          200kw
#
# [22606 rows x 10 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
import pandas as pd
import string
import nltk
import re

# Download stopwords if not already present
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

# Function to preprocess text
def preprocess_text(text):
    # Lowercase the text
    text = text.lower()
    # Remove punctuation (except hyphens)
    text = text.translate(str.maketrans("", "", string.punctuation.replace("-", "")))
    # Replace alphanumeric terms like "Ti-30Zr-5Al-3V-xFe" with a space-separated term
    text = re.sub(r'([a-zA-Z0-9]+(?:[-][a-zA-Z0-9]+)+)', r' \1 ', text)
    # Tokenize and remove stop words, short words (length < 3), and acronyms (all uppercase)
    tokens = [word for word in text.split() if word not in stop_words and len(word) > 2 and not word.isupper()]
    return " ".join(tokens)

# Load data from CSV
input_file = "merged_data.csv"  # Replace with your CSV file path
data = pd.read_csv(input_file)

# Combine 'title' and 'abstract' into a single string per document
data['title'] = data['title'].fillna("")  # Handle missing values
data['abstract'] = data['abstract'].fillna("")  # Handle missing values
data['combined'] = data['title'] + " " + data['abstract']

# Apply preprocessing to the combined text
data['processed'] = data['combined'].apply(preprocess_text)

# Prepare the text data for TF-IDF
sentences = data['processed']

# Initialize the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Compute the TF-IDF matrix
tfidf_matrix = vectorizer.fit_transform(sentences)

# Get the feature names (keywords)
keywords = vectorizer.get_feature_names_out()

# Extract and display top two keywords for each document
top_two_keywords = []  # To store top 3 keywords for each document
i = 0
for idx, row in enumerate(tfidf_matrix):
    scores = row.toarray()[0]  # Convert sparse matrix row to dense array
    # Pair keywords with their scores and sort them in descending order
    keyword_scores = sorted(zip(keywords, scores), key=lambda x: x[1], reverse=True)
    # Get the top 2 keywords
    top_keywords = [kw[0] for kw in keyword_scores[:3]]
    # Join top keywords as a string for the current document
    print(", ".join(top_keywords))
    print(i)
    i+=1
    top_two_keywords.append(", ".join(top_keywords))

'''''
# Add the top two keywords to the dataframe
data["Top_Two_Keywords"] = top_two_keywords

# Save the updated dataframe to a new CSV file
output_file = "data_with_top_two_keywords.csv"
data.to_csv(output_file, index=False)

print("Top two keywords extracted and saved to", output_file)
'''''
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Wachirawit
# [nltk_data]     Chumwong\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# alloys, corrosion, exhibit
# 0
# universities, creation, innovation
# 1
# hyperkyphosis, owd, thoracic
# 2
# farmlands, soils, conserved
# 3
# inch, cannulation, wire
# 4
# donation, organ, neighbor
# 5
# branching, levans, helix
# 6
# inductance, tpf, ii
# 7
# hrqol, tsh, lowered
# 8
# ufrs, irradiated, kgy
# 9
# aki, intensive, crrt
# 10
# pseudorapidity, pbpb, collisions
# 11
# gravity, radius, mass
# 12
# zikv, neurovirulence, neurovirulent
# 13
# sf, asr, pcnfs
# 14
# fall, falls, elderly
# 15
# aclf, clif, sofa
# 16
# aerial, elu, images
# 17
# acpcpna, rna, pna
# 18
# nanocellulose, mats, gelatin
# 19
# moodle, thinking, skills
# 20
# felids, ovarian, reproductive
# 21
# contingency, contingencies, operational
# 22
# ndn, rsu, vanet
# 23
# zinc, anode, bi2o3
# 24
# sepsis, bundles, ssc
# 25
# avs, kriging, sediment
# 26
# chairs, message, general
# 27
# nanopore, dna, sensor
# 28
# glutamate, extract, leaf
# 29
# pmddx41, ddx41, shrimp
# 30
# ep4, cox, pge2
# 31
# lbp, breaks, rest
# 32
# fuel, cell, molten
# 33
# spicy, taste, japanese
# 34
# nanoporous, pore, area
# 35
# bubble, taylor, tension
# 36
# top, neutralino, quark
# 37
# policy, teachers, implementation
# 38
# co2, mae, mea
# 39
# imranianum, saltern, phetchaburi
# 40
# sexual, activities, students
# 41
# lylei, diversity, genetic
# 42
# eca233, rotenone, rats
# 43
# letters, captcha, correct
# 44
# benzimidazoles, aldehydes, aromatic
# 45
# employee, organisational, broadcasting
# 46
# orbital, floor, endoscopic
# 47
# spasticity, hyperactivity, involuntary
# 48
# scope, repair, ureteroscope
# 49
# lignin, efb, depolymerization
# 50
# cips, pain, cni
# 51
# displacement, seismic, discussion
# 52
# odorata, adipocytes, flavonoids
# 53
# hypertrophic, rtl, lss
# 54
# psychiatrists, suicide, career
# 55
# apch, wpu, adhesive
# 56
# mechanic, mobile, auto
# 57
# catheter, intraluminal, spyglass
# 58
# quarks, vector, leptons
# 59
# physa, acuta, physidae
# 60
# ibu, patch, drug
# 61
# msea, speaking, demic
# 62
# pmi, attachment, insertion
# 63
# anesthesia, hours, post
# 64
# erns, csfv, igg
# 65
# emf, pmts, juno
# 66
# flour, bread, hom
# 67
# mah, tic, shell
# 68
# metaplasia, intestinal, reply
# 69
# labour, force, participation
# 70
# online, efficacy, self
# 71
# narcissistic, grandiosity, persistence
# 72
# he4, roma, ca
# 73
# ut, a1, aqp2
# 74
# stein, statistics, walk
# 75
# asparagine, synthetase, metabolic
# 76
# galaxies, millimeter, agn
# 77
# geopolymer, fly, ash
# 78
# waste, supermarket, management
# 79
# iaf, landmarks, po
# 80
# hcv, pregnant, women
# 81
# nonrelativistic, system, resonant
# 82
# ltc, elderly, care
# 83
# catalysts, surface, tungstate
# 84
# anorectal, pathophysiology, disorders
# 85
# fmr1, fmrp, cgg
# 86
# endoscopy, tage, thailand
# 87
# csc, chrysotoxine, src
# 88
# recombination, caninecvs, caninecv
# 89
# ywt7, yeasts, prototheca
# 90
# cep, p53, colorectal
# 91
# fn5y, l198, llcmk2
# 92
# dna, teeth, extracted
# 93
# sicticsioxtio2, shell, porous
# 94
# apap, kb, d1a
# 95
# lychee, litchi, neutrase
# 96
# bzx, paa, azobenzene
# 97
# sofc, separator, membrane
# 98
# river, saigon, aquifer
# 99
# 8tev, atlas, asymmetry
# 100
# mental, older, engagement
# 101
# bullies, victims, bullying
# 102
# sicp, aluminium, vol
# 103
# diagram, tool, class
# 104
# pollutant, removal, grease
# 105
# svmps, venom, mrv
# 106
# innovation, learning, business
# 107
# dental, clinics, settings
# 108
# cctv, throughputs, management
# 109
# cake, evco, hpmc
# 110
# periostin, urine, nephritis
# 111
# t2dm, rats, insulin
# 112
# aqua, editorial, immunity
# 113
# social, grams, media
# 114
# swcnts, electronic, calculations
# 115
# trade, financial, foreign
# 116
# ptcrc, pem, temperaturepressure
# 117
# crp, ab, aq
# 118
# dia, her2, manual
# 119
# iinear, milp, petrochemical
# 120
# levansucrase, levan, n251a
# 121
# tyrosinase, melanogenesis, flavonoids
# 122
# reply, chen, 00
# 123
# 7e, pvmsp, msp
# 124
# ocp, hydrazine, detection
# 125
# tmr, device, thermal
# 126
# news, prediction, textual
# 127
# assemblies, thermochromic, tails
# 128
# rikuzentakata, root, causes
# 129
# pyrene, pw1, consortium
# 130
# itp, prednisolone, relapsed
# 131
# sorption, sorbent, co2
# 132
# lived, particles, vertices
# 133
# spatial, strategy, solving
# 134
# photocatalysts, au3tio2, tio2
# 135
# evacuation, tsunami, drill
# 136
# cellulose, aerogel, sheet
# 137
# pulp, dental, force
# 138
# typhimurium, detection, cfu
# 139
# hausdorff, matematyczny, submanifold
# 140
# aging, healthy, prevalence
# 141
# tergitol, nonionic, surfactants
# 142
# learning, students, culture
# 143
# tilapia, fry, fish
# 144
# handed, neutrino, heavy
# 145
# norovirus, gastroenteritis, sporadic
# 146
# shoulder, breaks, rest
# 147
# bronchoscopes, cryobiopsy, transbronchial
# 148
# vpahpnd, hemocyanin, hmc
# 149
# chest, wall, position
# 150
# esblp, coli, pigs
# 151
# 33, il, psoriasis
# 152
# data, micro, clustering
# 153
# wheelchair, dental, services
# 154
# inhalant, craving, perfume
# 155
# enterocolitica, pyridoxine, enzyme
# 156
# tdcs, gait, msec
# 157
# ns15, succinic, isolates
# 158
# sexism, mindfulness, stereotype
# 159
# rebar, bond, resins
# 160
# cp, radiation, μsv
# 161
# metaspathius, zealand, nov
# 162
# orr, cnt, catalyst
# 163
# vos, sno2, photocatalytic
# 164
# higgs, boson, bottom
# 165
# bocas, hydrozoa, toro
# 166
# neutralino, excluded, gev
# 167
# baumannii, acinetobacter, dog
# 168
# self, sample, women
# 169
# particulate, crisis, perspectives
# 170
# cbct, scan, tube
# 171
# sex, bases, districts
# 172
# luxury, brand, values
# 173
# peh, cleansing, ecc
# 174
# sulfide, gossan, rocks
# 175
# basin, arc, triassic
# 176
# butene, metathesis, pretreatment
# 177
# elderly, smartphones, capabilities
# 178
# ccs, p4hb, fractures
# 179
# nmc, circumcision, staff
# 180
# nah, antiporters, flotnhaa
# 181
# dogs, senile, age
# 182
# proton, higgs, nonresonant
# 183
# sperm, spermatozoa, protocols
# 184
# proton, categories, inelastic
# 185
# sexuality, sexual, nurses
# 186
# lesions, mri, lcis
# 187
# hypophthalmus, pangasius, larnaudii
# 188
# nox, emission, so2
# 189
# research, national, projects
# 190
# intubation, ants, incident
# 191
# symmetry, row, lexicographic
# 192
# ltnps, emotional, cognitive
# 193
# hypertension, p0001, attitude
# 194
# qol, prompt, pharmacist
# 195
# v10, v20, risk
# 196
# european, studies, discipline
# 197
# resonances, proton, bottom
# 198
# chebyshev, polynomial, fim
# 199
# glycerin, dressing, phmb
# 200
# helpdesk, scalability, teams
# 201
# nocturia, luts, dribble
# 202
# danakil, seafloor, rifting
# 203
# tele, ontario, telemedicine
# 204
# cb, nps, mrc
# 205
# slns, mpe, blank
# 206
# pongrakhananon, varisa, person
# 207
# mortality, pm10, daily
# 208
# bniep, niep, sufficient
# 209
# carious, microtensile, bond
# 210
# otop, product, website
# 211
# hav, vaccination, students
# 212
# insidiosum, thda, rflp
# 213
# trip, travelers, travel
# 214
# chitosanalginate, cg, nanoparticles
# 215
# cpap, gdm, osa
# 216
# hornblende, granite, biotite
# 217
# politics, capital, chinese
# 218
# hydrogel, silver, dressing
# 219
# shear, rotating, stationary
# 220
# madecassoside, asiaticoside, eca
# 221
# gad, nitro, lipid
# 222
# kg, igeo, sediment
# 223
# spinel, corundum, corona
# 224
# hil, tire, steering
# 225
# cuxs, deposition, films
# 226
# adherence, antimalarial, drug
# 227
# effluvium, epinephrine, surgical
# 228
# biodegradability, pvcpbs, pbs
# 229
# sulfonated, furfural, sulfonic
# 230
# hvocs, ethoxylates, cocurrent
# 231
# akg, hydroxybenzoylformic, ketoglutaric
# 232
# osdefs, recombinant, sativa
# 233
# interrogatives, wh, english
# 234
# denture, transmission, pressure
# 235
# hms, amine, aminosilanes
# 236
# grovers, counting, algorithm
# 237
# bats, cov, infection
# 238
# inflation, term, kähler
# 239
# liability, legal, code
# 240
# ivcm, observers, sensitivity
# 241
# adiponectin, liver, fibrosis
# 242
# liver, failure, encephalopathy
# 243
# strains, plantarum, 22f
# 244
# hadronically, states, signal
# 245
# dσdϕ, kinematic, sections
# 246
# cnfhf, microextraction, hollow
# 247
# maas, cyanobacteria, mycosporine
# 248
# rock, hoek, brown
# 249
# cl, agnprs, silver
# 250
# maas, mycosporine, isolation
# 251
# cellulose, newspaper, composite
# 252
# incidents, paad, intubation
# 253
# emptying, jasb, gastric
# 254
# chitosan, gkg, broilers
# 255
# electrospinning, rotating, disk
# 256
# oxy, smedds, neuroprotective
# 257
# robot, rehabilitation, training
# 258
# rmeisa3, isoamylase3, ku50
# 259
# swabs, cloacal, sexing
# 260
# stone, unilateral, cystine
# 261
# icu, admissions, hospital
# 262
# epitopes, mirabilis, antigenic
# 263
# campylobacter, meat, chicken
# 264
# drill, noise, dental
# 265
# hpv16, cin, scc
# 266
# glycerol, lipid, synechocystis
# 267
# prediction, function, reward
# 268
# materials, natural, osteochondral
# 269
# socioscientific, argumentation, instruction
# 270
# shocking, edema, facial
# 271
# pubertal, kisspeptin, hypothalamic
# 272
# wheezing, episode, recurrent
# 273
# bedroom, asthma, aor
# 274
# soaes, ears, emissions
# 275
# kanban, production, cards
# 276
# znonio, hierarchical, porous
# 277
# ibpg, pyrolysis, gasification
# 278
# thalassemia, α37, hbe
# 279
# pthy100, hydroisomerization, hydrocracking
# 280
# classifier, classes, generalization
# 281
# anodizing, anodized, corrosion
# 282
# sharp, liftoff, motion
# 283
# polyion, cs, ha
# 284
# silica, mesostructured, nanocomposites
# 285
# dox, mcf, nucleus
# 286
# h2s, ccto, doped
# 287
# painful, metastases, radiotherapy
# 288
# straightness, chip, wavelet
# 289
# juice, mao, antioxidant
# 290
# paresis, spastic, centered
# 291
# pbi2, pbcl2, perovskite
# 292
# adhd, game, video
# 293
# quenching, fluorescence, go
# 294
# cmcs, icms, adsorption
# 295
# skeletal, dimensions, pharyngeal
# 296
# coronary, lipoprotein, cholesterol
# 297
# atx, livers, hepatic
# 298
# cowden, tumours, pituitary
# 299
# electric, graphene, δg
# 300
# construction, unsafe, system
# 301
# flnms, experiences, feeling
# 302
# depression, ido, cancer
# 303
# undrained, anisotropic, programming
# 304
# grip, strength, all
# 305
# abdesigner3d, uniprot, immunizing
# 306
# subtarsal, fibrosis, gvhd
# 307
# corona, staminal, oblong
# 308
# crane, captive, sharpii
# 309
# pericytes, pituitary, prolactinoma
# 310
# solder, laser, bonding
# 311
# plate, ballistic, projectile
# 312
# salinity, amino, kuruma
# 313
# sms, way, conscripts
# 314
# pleistocene, sung, khok
# 315
# carrageenan, p3ht, electromechanical
# 316
# procrastinators, achievement, academic
# 317
# physicians, icd, tpr
# 318
# hydrate, thf, methane
# 319
# glycogen, gcax, synechocystis
# 320
# tai, dai, languages
# 321
# huepo, prca, biosimilar
# 322
# saphan, optima, hin
# 323
# ltt, ifn, releasing
# 324
# defective, finished, process
# 325
# children, hiv, rcts
# 326
# violating, tev, limits
# 327
# rabies, prophylaxis, pathophysiology
# 328
# intermetallics, grain, refiner
# 329
# cmg, poag, peistent
# 330
# sunflower, minerals, sprouts
# 331
# sanitary, 2045, policy
# 332
# silver, adsorption, mp
# 333
# resonances, boson, heavy
# 334
# nisa, electrocatalytic, nps
# 335
# ccr5, marrow, codon
# 336
# ebv, pfs, mid
# 337
# nmpc, feedback, output
# 338
# jn2017754, ref, question
# 339
# 12, il, periodontal
# 340
# quotients, euler, rings
# 341
# limits, tev, proton
# 342
# insurance, cyber, risk
# 343
# text, embeddings, categorization
# 344
# glomerulonephritis, esrd, crescent
# 345
# pittii, carbapenem, nosocomialis
# 346
# sccmec, attb, orfx
# 347
# musical, improvisation, thai
# 348
# swcnts, acid, hydrothermal
# 349
# explicit, ingersoll, formula
# 350
# ceo, dividends, dividend
# 351
# raw2647, antioxidant, inflammatory
# 352
# idiosyncratic, returns, market
# 353
# inventions, innovation, renewable
# 354
# coverage, screening, effective
# 355
# ontology, pdm, project
# 356
# pcl, ad, nr
# 357
# retractions, lipschitz, hilbert
# 358
# ki, 67, pigs
# 359
# andreniformis, florea, apis
# 360
# esophageal, refluxate, transcutaneous
# 361
# parecoxib, isp, thoracotomy
# 362
# egcg, zinc, zno
# 363
# perthes, pillar, lateral
# 364
# polyp, coral, acropora
# 365
# cycloartobiloxanthone, apoptotic, cancer
# 366
# ald, disorders, hospitalized
# 367
# extubation, niv, reintubation
# 368
# laughter, buddha, buddhism
# 369
# copper, patterns, spraying
# 370
# purpureum, mine, phytoremediation
# 371
# vcos, intervention, exposure
# 372
# hexadecane, mangrove, phenanthrene
# 373
# gelation, monohydric, polyhydric
# 374
# ravenous, spirit, tradition
# 375
# ti, 4v, 6al
# 376
# bicarbonate, diisopropylamine, dipa
# 377
# telopodites, cambalopsidae, gonopods
# 378
# electrochromic, transparent, device
# 379
# aoa, ammonia, amoa
# 380
# ibd, ocp, association
# 381
# cinacalcet, bone, mbd
# 382
# kdm6a, kmt2d, kabuki
# 383
# endocardial, brugada, ablation
# 384
# electrode, cpan, aug
# 385
# adcigs, migration, velocity
# 386
# naming, software, convention
# 387
# barriers, power, trade
# 388
# essi, battery, lcc
# 389
# interconversion, oxime, dimensional
# 390
# brtn, betweenness, centrality
# 391
# formic, bicarbonate, reduction
# 392
# macrocarpa, leguminosae, mucuna
# 393
# microservice, logger, architecture
# 394
# oms2, btc, asiii
# 395
# so2, zeolites, zsm
# 396
# job, embeddedness, quit
# 397
# otcd, transcarbamylase, female
# 398
# bubble, viscosity, liquid
# 399
# somsa, volatile, stored
# 400
# dtpa, edta, underwater
# 401
# wps1, 2t, micromonospora
# 402
# greybody, factor, bound
# 403
# 41, sio2, pdmcm
# 404
# vein, ivc, iliac
# 405
# cypass, ndyag, laser
# 406
# isotopic, pb, granitoids
# 407
# follicle, stimulating, hormone
# 408
# bto, grained, coarse
# 409
# neurturin, irradiation, parasympathetic
# 410
# bending, blowing, strength
# 411
# rotating, disk, cone
# 412
# ideation, cultural, concepts
# 413
# movie, clustering, regression
# 414
# hbsag, hbcrag, pvr
# 415
# corolla, foetidiflora, ceropegia
# 416
# paclitaxel, scfv1c2, pt
# 417
# singular, weakly, crack
# 418
# ifa, ins, mg
# 419
# ecftaf, ftctdf, atv
# 420
# rpc, columns, fire
# 421
# amr, nsp, sectoral
# 422
# ground, earthquake, linear
# 423
# images, capsnet, tuberculosis
# 424
# security, regulations, banking
# 425
# nanofibers, nanofiber, composites
# 426
# emw, stvqt, rabbits
# 427
# embryos, forskolin, buffalo
# 428
# itns, rakhine, aor
# 429
# rhinitis, vitc, exercise
# 430
# leptons, proton, gev
# 431
# glycerol, eggshell, cao
# 432
# zn2, salicylaldimine, compounds
# 433
# fcnc, quark, top
# 434
# fam83h, pdlcs, mineral
# 435
# seizure, tle, patients
# 436
# inter, gaur, buffalo
# 437
# coq10, ala, ml
# 438
# arsenic, asiii, inorganic
# 439
# denture, masticatory, kapur
# 440
# higgs, boson, proton
# 441
# galaxies, star, starbursts
# 442
# ivabradine, dmvd, hrv
# 443
# mnr, nrmcc, mcc
# 444
# cuo, uniformity, particles
# 445
# femtocells, opna, femtocell
# 446
# trans, fragrans, pseuduvaria
# 447
# elderly, qol, life
# 448
# macaque, tailed, nprc
# 449
# ppe, im, polym
# 450
# hbs, miuml, anti
# 451
# neutralino, gev, mass
# 452
# border, pvdhps, pvmdr1
# 453
# outcome, exotropia, postoperative
# 454
# gabapentin, drinking, alcohol
# 455
# reproductive, maturation, shrimp
# 456
# zeolite, ipp, an
# 457
# cfp, biomass, corncob
# 458
# caloinophyllin, chromanone, inophyllum
# 459
# ht, pemfc, decentralized
# 460
# insertion, molar, normodivergent
# 461
# odorata, leaf, microscopic
# 462
# defect, classification, board
# 463
# ocbs, cells, humabs
# 464
# basis, gaussian, normal
# 465
# hydrogenation, nitrostyrene, catalysts
# 466
# operators, intercity, bus
# 467
# ingapn, lattice, gaas
# 468
# fruit, mango, put
# 469
# mall, artistic, shopping
# 470
# wind, terrain, cfd
# 471
# cnps, magnetic, synthesis
# 472
# radiation, protection, staff
# 473
# stop, words, keywords
# 474
# speaking, students, english
# 475
# agmss, sers, np
# 476
# skin, barrier, atopic
# 477
# professionalism, consensuses, emergency
# 478
# glsp, formulation, lot
# 479
# dhq, dihydroquinoline, fluorescence
# 480
# mnr, al2o3, nano
# 481
# vignette, sigmoid, bulky
# 482
# molars, mb2, canal
# 483
# masters, microneedle, microneedles
# 484
# cos, carboxylic, chitosan
# 485
# sphalerons, tev, black
# 486
# polyaniline, alkaline, scm
# 487
# gbm, targets, bbb
# 488
# biosensor, agnf, mirna
# 489
# smd, saline, irrigation
# 490
# ogd, assessment, application
# 491
# ulm, pile, load
# 492
# isolates, group, pichia
# 493
# authentication, wpa2, nfc
# 494
# ethanol, electrolyte, zinc
# 495
# bone, healing, mirifica
# 496
# amino, acids, intervals
# 497
# msm, hivaids, attitude
# 498
# depression, cap, canal
# 499
# escc, carboxamide, dihydroquinoline
# 500
# security, thailand, theorizing
# 501
# bite, raising, temporary
# 502
# typhoid, incidence, fever
# 503
# glurp, falciparum, aau
# 504
# authentication, enterprise, devices
# 505
# tzq, muons, s13tev
# 506
# stat1, baricitinib, transducer
# 507
# charged, higgs, boson
# 508
# tyrosine, coumaric, lyase
# 509
# prrsv, oral, fluid
# 510
# breeding, crane, cranes
# 511
# incs, nasal, smd
# 512
# pfcrt, artemisinin, chloroquine
# 513
# re, httpcreativecommons, orglicensesby
# 514
# degeneration, mmc, lamellae
# 515
# captive, liver, kidney
# 516
# policy, education, migrant
# 517
# tennis, player, professional
# 518
# psychodynamic, mentoring, underserved
# 519
# cholesteryl, hemin, curcuminoids
# 520
# myofibroblastic, sarcoma, aspiration
# 521
# buddhist, coexist, ideal
# 522
# physiology, processes, proteomics
# 523
# eco2, terrestrial, ecosystems
# 524
# kgmh, cream, ice
# 525
# anxiety, mafd, disorder
# 526
# blyp, ig2w, b3lyp
# 527
# payment, nfc, enabled
# 528
# farms, coli, resistance
# 529
# apixaban, warfarin, renal
# 530
# spermatocyte, stages, spermatogenesis
# 531
# labeled, supervised, training
# 532
# pictorials, affective, warning
# 533
# olefin, bio, syngas
# 534
# fe3o4np, pmampc, antifouling
# 535
# ppp, projects, private
# 536
# ride, travel, users
# 537
# sib, seq, toxicities
# 538
# grouting, liner, void
# 539
# llps, stopped, proton
# 540
# tcc, inoculant, soil
# 541
# elastic, plate, surface
# 542
# policy, poverty, fertility
# 543
# focei, saem, estimation
# 544
# pfbq, behaviours, feeding
# 545
# submaximal, mmvd, dogs
# 546
# ebv, pre, 2300
# 547
# succinic, aa7, np9
# 548
# tryptophan, dissatisfaction, quinolinic
# 549
# urticaria, socioeconomic, asia
# 550
# mmod, jaw, radiotherapy
# 551
# mass, quark, top
# 552
# gev, dark, matter
# 553
# aqp2, chip, water
# 554
# m2g, collagenase, mycosporine
# 555
# fatality, tsunami, arrival
# 556
# whisker, pla, crystallinity
# 557
# catchments, flow, ungauged
# 558
# aunrs, pmampc, dox
# 559
# cds, excipients, complexes
# 560
# diseases, offspring, transgenerational
# 561
# scrubbing, biomethane, biogas
# 562
# suture, anchor, meniscal
# 563
# professional, personal, growth
# 564
# galaxies, rotation, massive
# 565
# acr, determination, albumin
# 566
# canis, qcm, pcr
# 567
# media, children, multitasking
# 568
# interfacial, two, upward
# 569
# bmo, mice, aomdss
# 570
# limits, model, tev
# 571
# mir, nafld, 122
# 572
# top, jets, kinematic
# 573
# particle, azimuthal, charge
# 574
# dilatation, stricture, esophageal
# 575
# zinc, flow, zafb
# 576
# hepatitis, tdf, placebo
# 577
# akaisphecia, arita, gorbunov
# 578
# zinc, regeneration, battery
# 579
# dam, crm1, damnacanthal
# 580
# rhodamine, cr3, rhol
# 581
# lpp, nerve, mandibular
# 582
# qds, type, ii
# 583
# eeg, ear, the
# 584
# precast, molds, formulas
# 585
# jute, composites, nanoclay
# 586
# expressions, emotions, emotional
# 587
# rrt, fst, furosemide
# 588
# gvhd, magic, steroid
# 589
# hpv, 16, cin
# 590
# emax, rads, benign
# 591
# pharmacogenomics, genomic, drug
# 592
# module, liquid, multistage
# 593
# aragonite, nacre, plates
# 594
# capital, bhutan, social
# 595
# hen, fouling, cleaning
# 596
# eaf, bricks, 2546
# 597
# user, application, mobile
# 598
# juristic, act, contract
# 599
# pulse, plant, vacuoles
# 600
# cca, ov, infection
# 601
# aldosterone, asdt, transcripts
# 602
# rplgd, scrotum, rplgds
# 603
# trifluridinetipiracil, placebo, months
# 604
# bmp, bgn, lrr2
# 605
# cd20, thyroid, ptcs
# 606
# ivr, ivb, ssaes
# 607
# lightning, equation, angle
# 608
# gac, zeolite, lino35a
# 609
# znog, nanocomposite, cd2
# 610
# hsr, paclitaxel, premedication
# 611
# collisions, splitting, shower
# 612
# oral, cancer, tumors
# 613
# pani, ac, nanofiber
# 614
# project, csr, economic
# 615
# puerarin, tibia, bioavailability
# 616
# proton, multijet, event
# 617
# malaria, prompt, palaw
# 618
# colour, harmony, emotion
# 619
# csbs, inu, hgbs
# 620
# nan, ecotourism, city
# 621
# bougainvillea, dimethylflavone, spectabilis
# 622
# anesthesia, epidural, general
# 623
# mulberry, cardiometabolic, leaves
# 624
# silicone, scars, laser
# 625
# tdf, zol, bmd
# 626
# vector, lqs, leptoquark
# 627
# charginos, neutralinos, leptons
# 628
# esteem, delinquents, self
# 629
# btex, car, concentrations
# 630
# similarity, beam, laws
# 631
# xexe, collisions, gev
# 632
# myfas, brazilian, addiction
# 633
# emf, veto, magnetic
# 634
# kidney, transplant, transplantation
# 635
# spipm2, shrimp, yhv
# 636
# conical, slopes, drained
# 637
# clsm, pavement, base
# 638
# tie, nrtl, formic
# 639
# cranial, prophylactic, irradiation
# 640
# substudy, decline, copd
# 641
# enveloped, viruses, biomedical
# 642
# pmvrp15, wssv, shrimp
# 643
# lqs, scalar, lepton
# 644
# smartphone, tpb, online
# 645
# vector, proton, jet
# 646
# sva, isolates, full
# 647
# co2, absorption, mea
# 648
# gynecomastia, cushing, adrenocortical
# 649
# malaria, practice, severe
# 650
# qnpz, immediate, deferred
# 651
# chair, message, general
# 652
# iud, prevalence, cu
# 653
# lett, 763, phys
# 654
# thrombolysis, thrombosis, vein
# 655
# preeclampsia, hrg, uterine
# 656
# teleoperation, wave, controllers
# 657
# c3n4, ni2b, hydrogen
# 658
# stone, urologic, radiologic
# 659
# desired, countries, want
# 660
# building, energy, envelop
# 661
# higgsinos, search, higgs
# 662
# flow, lfts, elisa
# 663
# hbv, chb, polymorphisms
# 664
# fa, cp, microflowers
# 665
# svm, fuzzy, coding
# 666
# sorption, soil, mae
# 667
# hazardous, waste, liters
# 668
# trachomatis, chlamydia, sexually
# 669
# oil, fame, tungsten
# 670
# alma, asagao, μjy
# 671
# peat, decomposition, bacteria
# 672
# solutions, supersymmetric, so3
# 673
# benthic, oyster, sampling
# 674
# heuristic, coating, problem
# 675
# investor, measurement, financial
# 676
# il, peripheral, antidepressant
# 677
# listeria, contamination, classification
# 678
# cimt, carotid, household
# 679
# orr, complexes, copper
# 680
# cd4, cd328, culture
# 681
# diagrams, change, uml
# 682
# lignin, lnb, pvp
# 683
# s267f, hbv, ntcp
# 684
# thrombin, rvv, cdp
# 685
# tio2, h2s, oxygen
# 686
# lignocellulosic, biomass, digestion
# 687
# pdii, isotherm, extraction
# 688
# water, macarthurii, ptychosperma
# 689
# guano, bat, phosphorus
# 690
# poreskin, scar, burn
# 691
# husk, rice, adsorption
# 692
# schizophrenia, neurocognitive, psychosis
# 693
# rtl, earthquake, earthquakes
# 694
# basil, straw, hydrodistillation
# 695
# pontodrilus, litoralis, species
# 696
# concealing, sld, interferometer
# 697
# bus, remork, public
# 698
# hypokinesia, nocturnal, dopaminergic
# 699
# nash, fibrosis, asia
# 700
# dolomite, calcined, mgo
# 701
# quasoq, 6th, workshop
# 702
# sedimentation, bare, mangrove
# 703
# home, locations, cdr
# 704
# sc, znosl, adsorption
# 705
# inverted, diagram, footings
# 706
# membranes, srnf, nanofiltration
# 707
# mycourseville, lms, learning
# 708
# respiratory, hfnc, distress
# 709
# crepidium, orchidaceae, species
# 710
# brugada, arrhythmia, syndrome
# 711
# exchangers, hen, pfhes
# 712
# avian, avh5, huh1
# 713
# apoe4, carriers, allele
# 714
# marriages, political, monogamy
# 715
# cd8, hand, hiv
# 716
# cuncs, al3, fluorescent
# 717
# alu, methylation, leukocytes
# 718
# cx, df, vdw
# 719
# pseudorapidity, charged, proton
# 720
# mdd, insulin, β1
# 721
# jet, cross, section
# 722
# spin, mass, cartan
# 723
# tewl, infants, ceramide
# 724
# nipples, supernumerary, twins
# 725
# ττ, significance, deviations
# 726
# pcv3, colostrum, viremic
# 727
# extraction, electromembrane, chromiumvi
# 728
# reactors, nickel, methane
# 729
# alsb, films, optoelectronic
# 730
# mpl, angles, radiography
# 731
# mangium, nemoralis, fertilizer
# 732
# ahi, aes, biopsy
# 733
# footing, adhesion, interface
# 734
# calcifications, breast, stereotactic
# 735
# shoreline, port, rayong
# 736
# occupancy, sustainable, dimension
# 737
# surface, pcl, topologies
# 738
# sjs, ten, overlap
# 739
# hcm, cats, survival
# 740
# genes, salt, kdml105
# 741
# egg, salmonella, behavior
# 742
# nhris, civil, etos
# 743
# relapse, virological, hbv
# 744
# bcnc, bcncs, cationic
# 745
# aging, reappraisal, emotional
# 746
# chelifer, stag, male
# 747
# ferrate, pacl, coagulation
# 748
# higgs, neutral, mssm
# 749
# pns, complexes, inclusion
# 750
# heart, transplant, incidence
# 751
# hpv, ngs, lipa
# 752
# cdrs, towers, mobile
# 753
# transmitters, handheld, mouth
# 754
# lepton, mass, predictions
# 755
# pena, lactam, pseudomallei
# 756
# rop, infants, grader
# 757
# foods, healthy, kcmh
# 758
# vibrio, dgge, pcr
# 759
# zikv, chikv, denv
# 760
# mycobacterium, asiaticum, pulmonary
# 761
# bpmn, transformation, model
# 762
# breaks, discomfort, pain
# 763
# cutting, wear, force
# 764
# boson, higgs, signal
# 765
# petri, promela, net
# 766
# rarefied, flow, gas
# 767
# layered, elastic, displacement
# 768
# leadership, teacher, teachers
# 769
# coffee, dung, elephant
# 770
# ltfu, art, ashr
# 771
# pythiosis, carotid, emboli
# 772
# security, banking, requirements
# 773
# agitated, strains, komagataeibacter
# 774
# droplets, dislocations, nucleation
# 775
# thf, znfe, znal
# 776
# rail, projects, master
# 777
# land, sediment, po4
# 778
# upr, neuroprogressive, pathways
# 779
# hbcs, paksé, heterozygosity
# 780
# isotope, speleothems, speleothem
# 781
# same, sign, proton
# 782
# deamidation, deamidated, protein
# 783
# cassia, garrettiana, grandis
# 784
# greulich, pyle, age
# 785
# co2, oil, oilfield
# 786
# crizotinib, chemotherapy, pfs
# 787
# cover, rectangle, clipped
# 788
# sericin, mitochondrial, dehydrogenase
# 789
# alkaloids, aporphine, spinosus
# 790
# aml, patients, elderly
# 791
# asd, mothers, subdiagnoses
# 792
# annealing, magnetic, alloys
# 793
# aristolochia, herbal, species
# 794
# snapshot, ophthalmology, 00
# 795
# geitlerinema, marine, cpca
# 796
# arbitrariness, activism, constitutional
# 797
# preface, 00, 000
# 798
# ccbcd, ccb, rmβcd
# 799
# corrigendum, fluid, 101016jpnucene201712003
# 800
# arch, arches, alveolar
# 801
# engagement, hrdc, work
# 802
# tourists, food, local
# 803
# svm, choice, separable
# 804
# cryobiopsy, ild, transbronchial
# 805
# mlva, ngs, coupled
# 806
# metakaolin, kaolin, fly
# 807
# fluoride, b03, rinsing
# 808
# าต, scc, บอนไดออกไซด
# 809
# steels, corrosion, nickel
# 810
# patterning, paper, mask
# 811
# zn, hydrogen, etoh
# 812
# tio2, black, plasma
# 813
# uav, environmental, haze
# 814
# hydrogenation, co2, fe
# 815
# methacrylic, acid, hydrogel
# 816
# epinephrine, prefilled, epipen
# 817
# spermatogenesis, hormonal, transwomen
# 818
# charm, hadrons, ppb
# 819
# proms, olp, interpretability
# 820
# mercury, fluorescence, rhodamine
# 821
# freshwater, ecosystems, stakeholders
# 822
# sif, equations, cracked
# 823
# wssv134, pmhhap, wssv
# 824
# acpcpna, r4, duplex
# 825
# tea, miang, leaves
# 826
# wine, futures, winemaker
# 827
# ur, pemfc, air
# 828
# higgs, proton, boson
# 829
# infographics, census, nso
# 830
# tremor, parkinsons, thalamo
# 831
# scs, hydrogel, formulation
# 832
# duality, string, btz
# 833
# antenna, radiating, flexible
# 834
# multiplet, supergravity, supersymmetry
# 835
# hospitalizations, care, diabetes
# 836
# likay, cartoon, comics
# 837
# weight, icev, laden
# 838
# krusei, mannan, dcs
# 839
# preface, 00, 000
# 840
# granitoids, loei, phu
# 841
# attitudes, educational, students
# 842
# acrylate, 3fma, co
# 843
# surfactant, doping, ppp
# 844
# arborinine, parva, cervical
# 845
# keywords, meanings, plural
# 846
# igm, schizophrenia, deficit
# 847
# pdtio, agtio, atoms
# 848
# screws, uncoated, coating
# 849
# gesture, hand, gestures
# 850
# gdd, operative, implantation
# 851
# comprehension, students, lds
# 852
# carbonyl, ros, protein
# 853
# hdf, ol, survival
# 854
# infused, objects, embedding
# 855
# cuonps, drosophila, toxicity
# 856
# ti, tio, heterostructured
# 857
# rickettsia, felis, dogs
# 858
# hcv, chc, burden
# 859
# rnfl, normative, database
# 860
# boonchoo, boonchu, sritularuk
# 861
# catalyst, oil, shells
# 862
# hiv, research, priority
# 863
# dehydrogenation, oxidative, acetaldehyde
# 864
# bamboo, charcoal, vinegar
# 865
# writing, tep, vignette
# 866
# vietnamese, iris, angle
# 867
# silver, colloids, nanoparticles
# 868
# photo, sightseeing, places
# 869
# polarization, angular, 006stat
# 870
# catalyst, htcdrb, hydrothermal
# 871
# iron, ferroptosis, peroxidation
# 872
# fgfr3, bgj398, alterations
# 873
# lactobacillus, l34, rhamnosus
# 874
# gc, mdgc, offer
# 875
# bile, chicks, fat
# 876
# agt1r, activation, erk
# 877
# baff, abmr, recipients
# 878
# cenc, corneal, vip
# 879
# fractionation, heavy, contaminated
# 880
# chloride, ions, extraction
# 881
# tio2, gnds, npgnd
# 882
# pb, gevc, fragmentation
# 883
# kno3, nano3, molten
# 884
# tio2, chp, eccac15
# 885
# endocarditis, dog, enterobacter
# 886
# enghoff, gen, srisonchai
# 887
# pessimism, pessimistic, aci
# 888
# epithelial, organoids, spheroids
# 889
# adsorption, iii, battery
# 890
# lcu, feature, hevc
# 891
# aunp, il, sepsis
# 892
# bmds, ptpn11e76k, mutation
# 893
# endotoxin, gut, mice
# 894
# hiv, clinic, naat
# 895
# sepsis, implementation, period
# 896
# choleraesuis, isolates, ciprofloxacin
# 897
# rainfalls, rainfall, flood
# 898
# grass, napier, pretreatment
# 899
# groomed, jet, pbpb
# 900
# leptons, proton, hadrons
# 901
# capsici, anthracnose, m10
# 902
# speciosa, mitragyna, matk
# 903
# p2clan, conductivity, electrical
# 904
# dipentylammonium, sigma, receptor
# 905
# filament, absgo, printing
# 906
# mcc, hybrid, films
# 907
# interface, lms, mycourseville
# 908
# mcc, acid, pws
# 909
# goats, cae, ruminant
# 910
# gfr, ckd, epi
# 911
# pregnant, women, hypertension
# 912
# neutrophils, nmr, pma
# 913
# groundwater, rainfall, table
# 914
# n2o, la03sr07co07fe03o3, nitrous
# 915
# cinnamon, nanoemulsions, oil
# 916
# taxes, taking, risk
# 917
# preface, 00, 000
# 918
# bioethanol, biodiesel, ethanol
# 919
# vertebral, metastasis, body
# 920
# ovulation, oestrous, bitches
# 921
# groundtea, briquettes, carbonized
# 922
# aki, abdominal, laparoscopic
# 923
# lutein, transfer, mass
# 924
# manga, hazardshazardous, students
# 925
# biosurfactant, gelatin, nanofibers
# 926
# restaurant, color, emotional
# 927
# blues, postpartum, allopregnanolone
# 928
# mrsa, sstis, skin
# 929
# fn6, saprophyticus, fn1
# 930
# teacher, teachers, education
# 931
# driver, acceleration, sensors
# 932
# abutment, titanium, histological
# 933
# wbrt, pcnsl, patients
# 934
# microemulsion, hld, washing
# 935
# propane, dehydrogenation, pt08in
# 936
# pruriens, neurite, outgrowth
# 937
# edition, 4th, thyroid
# 938
# modulation, carrier, vector
# 939
# contrast, mvd, vesselsmm2
# 940
# thalhbe, beta, transfusion
# 941
# pineapple, phb, core
# 942
# symptoms, daps, noxpro
# 943
# plantar, achilles, tendon
# 944
# µmoll, sw620, ic50
# 945
# seizure, freedom, epilepsy
# 946
# software, estimation, cost
# 947
# dam, agency, infrastructure
# 948
# standard, proton, top
# 949
# rice, seedling, kdml105
# 950
# ion, divalent, ammonium
# 951
# c3r, mg, rutinoside
# 952
# conserve, stick, tbhq
# 953
# perinatal, tenofovir, placebo
# 954
# crassna, mangiferin, pharmacognostic
# 955
# sensor, vapors, methanol
# 956
# carbetocin, pgf2α, sows
# 957
# expressor, cni, nephrotoxicity
# 958
# bacterin, chitosan, route
# 959
# cream, btx, liposomal
# 960
# csitl, crystals, optical
# 961
# monsters, separation, bin
# 962
# rha, paste, nanofibers
# 963
# piece, commentary, leadership
# 964
# tracy, operators, singh
# 965
# antibiotic, surgery, orthognathic
# 966
# midfoot, pedobarography, hindfoot
# 967
# belcheri, microsatellites, polymorphic
# 968
# commitment, mcs, marital
# 969
# msc, mscs, ulna
# 970
# prioritise, sharing, cochrane
# 971
# ibuprofen, pectin, hydrogels
# 972
# plahipswf, flame, wpcs
# 973
# internet, males, females
# 974
# sericin, tyrosinase, hyperpigmentation
# 975
# stickers, consumers, sticker
# 976
# kisspeptin, ovarian, ir
# 977
# inversion, gabor, seismic
# 978
# vnr, cellulose, hydrogels
# 979
# cancer, csc, lung
# 980
# exenteration, urgent, pelvic
# 981
# loan, cash, format
# 982
# restaurant, entrepreneurs, business
# 983
# nanofilms, tio2, coated
# 984
# αsyn, down, native
# 985
# aging, healthy, nurses
# 986
# agtio2, mechanothermal, μmolhgcat
# 987
# distributions, proton, dark
# 988
# skin, hydration, elasticity
# 989
# schizophrenia, iga, deficit
# 990
# snake, envenomation, predictive
# 991
# infectious, emerging, medicine
# 992
# pyruvate, trj, axon
# 993
# india, asean, exchanges
# 994
# hiv, sti, condom
# 995
# pdiccp, palladium, carbonate
# 996
# biofeedback, therapy, patients
# 997
# rssi, amplifier, cmos
# 998
# levenberg, marquardt, calculation
# 999
# mangostana, pan, mats
# 1000
# embedding, categorization, text
# 1001
# agents, predetermined, shifts
# 1002
# broadcast, theoretic, complexity
# 1003
# albumin, tpe, trcs
# 1004
# complexes, copperii, nitrobenzoate
# 1005
# oct4, cav, promotes
# 1006
# ppy, fpypss, co
# 1007
# health, care, national
# 1008
# elevator, elevators, gui
# 1009
# mangosteen, mgpvac, pvac
# 1010
# nurses, australian, caring
# 1011
# 80211p, ieee, blind
# 1012
# eggshell, waste, hydroxyapatite
# 1013
# hydrate, dissociation, hollow
# 1014
# ycf, bifidobacterium, scgoslcfos
# 1015
# depression, prenatal, postpartum
# 1016
# bacteriophage, gastrointestinal, engineered
# 1017
# freshener, shrink, sleeve
# 1018
# hiv, children, infected
# 1019
# mci, cerad, controls
# 1020
# crystallization, melting, temperature
# 1021
# iloprost, slices, pulp
# 1022
# right, left, to
# 1023
# financial, myanmar, savings
# 1024
# football, tournament, factors
# 1025
# synovial, nmr, bruker
# 1026
# bt474, apigenin, mangostin
# 1027
# blue, ratanakiri, zircon
# 1028
# σtt, jj, tt
# 1029
# mercury, asd, neurotoxic
# 1030
# commodity, markets, behavioral
# 1031
# methanogenic, thermophilic, mesophilic
# 1032
# cipplga, loaded, cip
# 1033
# service, technology, satisfaction
# 1034
# amphipol, apol, filaments
# 1035
# version, ipss, problems
# 1036
# qnms, black, string
# 1037
# starches, msk, amylopectin
# 1038
# igm, dpss, adducts
# 1039
# sketchbook, students, reflective
# 1040
# rind, edsbs, edsb
# 1041
# submodules, prime, nearly
# 1042
# planus, lichen, challenge
# 1043
# kcnh2, lqts, genetic
# 1044
# dcbr, dichlorocarbene, chlorine
# 1045
# teachers, autonomy, access
# 1046
# nephrolithiasis, urinary, descendants
# 1047
# eem, mangostin, b16f10
# 1048
# coxsackievirus, a71, enterovirus
# 1049
# bia, lotus, biosynthesis
# 1050
# informal, lenders, borrower
# 1051
# coq10, dogs, mmvd
# 1052
# deceptive, false, responsibility
# 1053
# hbv, ifnλ3, ifnλ
# 1054
# linuron, degradation, polar
# 1055
# shrimp, atl8, rs
# 1056
# productive, behaviours, participation
# 1057
# tools, vle, learners
# 1058
# amansii, fermentation, stipitis
# 1059
# rha, mortar, compressive
# 1060
# gevc, azimuthal, pbpb
# 1061
# urinary, excretion, stone
# 1062
# captcha, eye, movement
# 1063
# plantations, rubber, age
# 1064
# species, metaphire, new
# 1065
# trial, fst, rrt
# 1066
# enr, go, aminosilane
# 1067
# yhv, pmyrp65, rpmyrp65
# 1068
# 2ltrzfp, expression, lentiviral
# 1069
# radicals, arylflavan, motleyi
# 1070
# cave, visitors, infections
# 1071
# periodontitis, glycaemic, ifg
# 1072
# leishmania, leishmaniasis, mundinia
# 1073
# dspp, dentin, pulp
# 1074
# nts, porphyrin, h2o2
# 1075
# pullulans, aureobasidium, postharvest
# 1076
# pulse, video, wave
# 1077
# 21, 5p, mir
# 1078
# substructure, observables, jet
# 1079
# xeel, intelectin, frog
# 1080
# lymphoma, nhl, tnkcl
# 1081
# rsfc, ahi, voxelwise
# 1082
# riser, sesre, flux
# 1083
# ofhcnzoic, ethylhexanol, ai
# 1084
# alkaloids, ic50, lipoxygenase
# 1085
# osgasr3, sativa, rice
# 1086
# ieee1888, gateway, bluetooth
# 1087
# echonet, lite, mqtt
# 1088
# reforming, sofc, external
# 1089
# segnet, segmentation, resolution
# 1090
# dsrna, vlps, pstdnv
# 1091
# threshold, verb, generation
# 1092
# theun, branding, hydropower
# 1093
# lotus, bia, nuciferine
# 1094
# empowerment, socioeconomic, hiv
# 1095
# cone, dimitra, beam
# 1096
# nursing, neonatal, cambodia
# 1097
# servitization, chemical, framework
# 1098
# nanoclay, masterbatch, aerogel
# 1099
# educators, competences, dental
# 1100
# evans, ligature, periodontitis
# 1101
# srs, neuroendocrine, metastases
# 1102
# diabetes, glycemic, prevalence
# 1103
# ahr, ami, heart
# 1104
# fault, fuzzy, gustafson
# 1105
# lewis, acids, copolymerization
# 1106
# methylcoumarins, dialkyloxy, dihydroxy
# 1107
# alu, methylation, sirna
# 1108
# goat, plasmodium, goats
# 1109
# jet, parton, hadronization
# 1110
# films, methylene, layered
# 1111
# il111i, column, polar
# 1112
# stirt, zahlbr, baileyi
# 1113
# agitation, dextromethorphanquinidine, dementia
# 1114
# tuberculosis, hiv, infected
# 1115
# doxorubicin, nanoemulsion, encapsulated
# 1116
# oxalate, nephropathy, patients
# 1117
# boson, resonances, proton
# 1118
# schur, zeta, functions
# 1119
# iaf, heat, system
# 1120
# enr, plaenr, nsio2
# 1121
# attitude, antibiotics, knowledge
# 1122
# igm, hypomanic, symptoms
# 1123
# pdms, thin, film
# 1124
# prps, ocbs, sized
# 1125
# smart, flipped, cufsa
# 1126
# males, gibbon, handed
# 1127
# sausages, packaged, qdi
# 1128
# et770, ftsz, jw0093
# 1129
# cart, transition, hiv
# 1130
# brand, branding, salespeople
# 1131
# gut, leaky, assays
# 1132
# skewness, supplier, buyers
# 1133
# wound, bcsp, bactigras
# 1134
# bhd, process, litersday
# 1135
# groundwater, drastic, shallow
# 1136
# corpus, consultation, collocations
# 1137
# energy, administrative, cost
# 1138
# threads, thread, argentometric
# 1139
# cte, cakes, sponge
# 1140
# mice, igm, sigm
# 1141
# companion, animals, diseases
# 1142
# so4, so3, gauge
# 1143
# cigs, 135, 112
# 1144
# psychic, distance, service
# 1145
# singing, duets, song
# 1146
# requirement, smes, requirements
# 1147
# scz, panss, fep
# 1148
# etching, plasma, beam
# 1149
# figure, incorrect, 101007jhep092017106
# 1150
# pair, gev, squark
# 1151
# platooning, beaconing, desynchronization
# 1152
# gel, tin, resorcinol
# 1153
# hofstadter, exterior, angles
# 1154
# leptospirosis, lepto, score
# 1155
# anxiety, drinking, depressive
# 1156
# flavonoids, biology, production
# 1157
# reporting, service, mimetic
# 1158
# converters, pwm, back
# 1159
# ndv, chickens, old
# 1160
# gene, disease, associations
# 1161
# asper, ache, fractions
# 1162
# bleeding, tc, hemostatic
# 1163
# derivatized, substituent, analytes
# 1164
# lsp, gev, diphoton
# 1165
# alumni, segment, so
# 1166
# hpw, sba, nanocatalysts
# 1167
# films, thick, pzt
# 1168
# parton, next, boson
# 1169
# nov, atopochetus, litostrophus
# 1170
# tutoring, shadow, private
# 1171
# tnbc, mtnbc, stage
# 1172
# life, kathmandu, elderly
# 1173
# hierarchy, stereo, label
# 1174
# pharmacy, ethical, profession
# 1175
# zr, phase, alloys
# 1176
# jet, gluino, violating
# 1177
# irx, attenuation, galaxies
# 1178
# denticola, mmp, pdl
# 1179
# iphones, obsolescence, looking
# 1180
# ปกรณ, ใช, sop
# 1181
# policies, inventory, eoq
# 1182
# deficient, ba, sr
# 1183
# 1550, hair, igf
# 1184
# aluminizing, pack, heating
# 1185
# pir, switch, mvc
# 1186
# inks, ink, films
# 1187
# migraine, neuropeptide, attack
# 1188
# carbamazepine, hla, induced
# 1189
# fluoride, apf, brackets
# 1190
# learning, class, grades
# 1191
# proton, decaying, resonance
# 1192
# rspipm5, spipm5, shrimp
# 1193
# nrbc, 6800, bc
# 1194
# pyrolysis, oil, pyrolyzed
# 1195
# abs, plapla, blends
# 1196
# amb, lipid, drug
# 1197
# table, lle, tie
# 1198
# prompt, pharmaceutical, short
# 1199
# weibull, re1, re12
# 1200
# loohsodnox, abuse, elts
# 1201
# kiawe, damage, water
# 1202
# duck, eggs, contamination
# 1203
# student, alcohol, mining
# 1204
# commensurate, structure, sc
# 1205
# spodumene, cordierite, cookware
# 1206
# doctorate, dissertation, seminar
# 1207
# agility, npd, organization
# 1208
# vp40, ctd, ntd
# 1209
# rats, snr, des
# 1210
# cadmium, edta, napier
# 1211
# vpahpnd, toxin, lvalf
# 1212
# packaging, food, intelligent
# 1213
# research, alhiv, hiv
# 1214
# papillae, tongue, lingual
# 1215
# butanol, tolerance, subtilis
# 1216
# phantoms, paediatric, dimitra
# 1217
# coral, healthiness, entropy
# 1218
# vlqs, pair, production
# 1219
# phrases, song, phrase
# 1220
# ivlbcl, orthodeoxia, lymphoma
# 1221
# tpad, para, grass
# 1222
# crs, ancestry, endotypes
# 1223
# pylori, asean, consensus
# 1224
# camsap3, emt, microtubule
# 1225
# alloys, amorphous, ti
# 1226
# wheezing, nebulized, hypertonic
# 1227
# actinomadura, sda37t, strain
# 1228
# nursing, students, indonesian
# 1229
# thiophene, perylene, porphyrin
# 1230
# mesoscopic, strained, vo2
# 1231
# braf, mutation, v600
# 1232
# seawater, uranium, gel
# 1233
# fat, carboxytherapy, circumference
# 1234
# caisson, pullout, suction
# 1235
# top, excited, quark
# 1236
# tripped, rollover, rollovers
# 1237
# auroc, model, cohort
# 1238
# lps, neuroimmune, quin
# 1239
# construction, precast, toward
# 1240
# nlsp, momentum, susy
# 1241
# srisonchai, enghoff, panha
# 1242
# cht, adsorptiondesorption, co2
# 1243
# mdd, studies, participants
# 1244
# nafld, statin, alcoholic
# 1245
# ffi, th, subscale
# 1246
# learning, solving, creative
# 1247
# animation, progress, waiting
# 1248
# bi2o3, photocatalysts, absorption
# 1249
# eml2, brain, tissue
# 1250
# gasification, caomgo, mmolgbiomass
# 1251
# refixation, bole, sylvestris
# 1252
# model, twisted, chiral
# 1253
# radiology, epidemiology, public
# 1254
# higgs, boson, pseudoscalar
# 1255
# railway, embankments, subgrade
# 1256
# curdg, curcumin, antinociceptive
# 1257
# finm, seqm, infinite
# 1258
# strategy, firms, performance
# 1259
# medical, radiology, physics
# 1260
# asean, trade, agreements
# 1261
# pregnancy, percent, respondents
# 1262
# hepatitis, lipid, patients
# 1263
# seed, seedsfruits, assemblages
# 1264
# nanosystems, chitosan, spray
# 1265
# anomalous, outliers, assemblage
# 1266
# sand, trypanosoma, fly
# 1267
# pulse, hrv, rppg
# 1268
# ppb, multiplicity, radii
# 1269
# monsoon, sundaland, asian
# 1270
# purvalanol, mcl, gm
# 1271
# alu, asd, methylation
# 1272
# earthquakes, seismicity, upcoming
# 1273
# somsa, antioxidant, peel
# 1274
# pbs, snc, films
# 1275
# poetry, metadata, corpus
# 1276
# co2emissions, arimax, model
# 1277
# tio2, chitosan, ethylene
# 1278
# basalt, fibers, fiber
# 1279
# h5n1, autopsy, avian
# 1280
# dka, วท, โตอะซ
# 1281
# mfc1, mfc3, mfc6
# 1282
# blo, rblo, allergen
# 1283
# mixing, screw, sharkskin
# 1284
# mgo, powder, ray
# 1285
# gccm, geosynthetic, cementitious
# 1286
# daidzein, cd, daidzeindm
# 1287
# assurance, cbct, quality
# 1288
# week, omalizumab, asthma
# 1289
# nanocellulose, extraction, applications
# 1290
# tacrolimus, polymorphisms, por28
# 1291
# colonoscopy, network, video
# 1292
# socio, economic, matched
# 1293
# impeller, torque, power
# 1294
# mtbrif, xpert, ptb
# 1295
# dox, fa, senpstmc
# 1296
# moxifloxacin, fluorescence, determination
# 1297
# rule, ontology, recommendation
# 1298
# fiebig, hiv, interruption
# 1299
# cdrmo, disaster, cbdrm
# 1300
# postoperative, analgesia, tka
# 1301
# debye, particle, pore
# 1302
# thoron, 220rn, radon
# 1303
# catalyst, bacl2, razor
# 1304
# zinc, sds, koh
# 1305
# jgrg, 2018since, lunar
# 1306
# liver, transplantation, transplant
# 1307
# lab, shrimp, vpahpnd
# 1308
# ets, concrete, bond
# 1309
# benzaldehyde, hba, deprotection
# 1310
# nonlocal, theories, field
# 1311
# pvf, ifc, articular
# 1312
# ranibizumab, plgf, responder
# 1313
# korean, chinese, white
# 1314
# cusio2, catalysts, dmo
# 1315
# heuristics, usability, evaluators
# 1316
# sul, dpnr, patch
# 1317
# prrsv, treg, lungs
# 1318
# levofloxacin, enantiomeric, isotherm
# 1319
# lysosomal, activation, parp
# 1320
# branes, m5, m2
# 1321
# analogues, melodorinol, cytotoxicity
# 1322
# structure, host, pressure
# 1323
# rtl, leukocyte, knee
# 1324
# forests, pine, water
# 1325
# hbp, blood, urban
# 1326
# formula, uniform, bound
# 1327
# whc, additives, nacl
# 1328
# pmf, lcupc, setup
# 1329
# prima, b2m, prognostic
# 1330
# histamine, histidine, detection
# 1331
# depression, cause, all
# 1332
# tumor, cells, il4
# 1333
# graph, consistency, transition
# 1334
# hydrochar, htc, acid
# 1335
# pw, mcc, parawood
# 1336
# dom, dfe, relationships
# 1337
# wrapped, aerogelsilver, pani
# 1338
# blaoxa, blandm, carbapenemase
# 1339
# σtt, section, measurement
# 1340
# gravity, mass, bounds
# 1341
# leadership, authentic, school
# 1342
# idsa2012, epos2012, abrs
# 1343
# marmoset, animal, callithrix
# 1344
# bicarbonate, reduction, mvs
# 1345
# vapors, voc, fluorescent
# 1346
# pn, sbs, dependence
# 1347
# sawdust, gaseous, gasification
# 1348
# bs0, bs0π, x5568
# 1349
# nasal, tip, nose
# 1350
# ptswcnt, mfc, cathode
# 1351
# αsyn, fibrils, supramolecular
# 1352
# aqp, membranes, tio2
# 1353
# codes, abelian, complementary
# 1354
# google, nowcasting, trends
# 1355
# practices, value005, perceived
# 1356
# ev71, recombinant, viruses
# 1357
# authoritarianism, class, imperial
# 1358
# rubber, dcnr, dpnr
# 1359
# ckd, hiv, patients
# 1360
# health, achieve, plianbangchangpurpose
# 1361
# cthpt, tocopherol, chlorophyll
# 1362
# chitosan, gnrh, spermatogonia
# 1363
# pvtrap, domain, antibodies
# 1364
# orf1p, bladder, hne
# 1365
# backward, asymmetry, sin2θeffℓ
# 1366
# βcds, complexes, inclusion
# 1367
# proton, quarks, search
# 1368
# eeg, encephalitis, pdr
# 1369
# sle, chromosome, gpr173
# 1370
# leadership, global, school
# 1371
# fcγriib, cortical, sle
# 1372
# müller, levator, conjunctival
# 1373
# tic, clo, atherosclerosis
# 1374
# nhbow, office, neck
# 1375
# il, deciduous, sheds
# 1376
# dengue, demographic, spectrum
# 1377
# exergy, exergetic, pinch
# 1378
# scm, methanol, biodiesel
# 1379
# pathology, abnormalities, mdd
# 1380
# abcg2, abcb1, rescue
# 1381
# nose, dorsum, intercanthal
# 1382
# sil, depression, 6r
# 1383
# estimation, ensemble, effort
# 1384
# tio2, glycerol, gcd
# 1385
# earthquake, tarlay, site
# 1386
# ev71, vp2, gst
# 1387
# ammonia, aob, nri
# 1388
# temporal, ltle, rtle
# 1389
# promela, code, invariants
# 1390
# pain, cold, n35
# 1391
# quenching, datpp, fluorescence
# 1392
# anchors, suction, misalignment
# 1393
# military, civil, relations
# 1394
# waste, recycling, bank
# 1395
# analytics, business, organizations
# 1396
# jet, pbpb, collisions
# 1397
# magnifying, injective, surjective
# 1398
# network, conference, sdn
# 1399
# schizophrenia, memory, mmse
# 1400
# bamboo, tdg, mechanical
# 1401
# schizophrenia, neurocognitive, faars
# 1402
# co2, carbon, porous
# 1403
# ffs, properties, foods
# 1404
# nanocrystalline, hydroxyapatite, microwave
# 1405
# regulation, pharmaceutical, tensions
# 1406
# educators, dental, educational
# 1407
# crack, loading, generalized
# 1408
# brine, lswf, calcium
# 1409
# blow, polyethylene1, direction
# 1410
# hydrochar, hydrothermal, btw
# 1411
# alluropus, rhysida, 1845
# 1412
# pseudonocardia, smc, mangrovi
# 1413
# membrane, developments, co2
# 1414
# illicit, 2003, 2001
# 1415
# vanadate, renal, camp
# 1416
# keratitis, eyes, infectious
# 1417
# emissions, construction, exhaust
# 1418
# semantic, environmental, computing
# 1419
# proton, measurement, s13
# 1420
# vonoprazan, esd, ulcers
# 1421
# lactate, osmosis, bwro
# 1422
# karposibracon, braconini, papua
# 1423
# mac, internet, cu
# 1424
# higgs, boson, production
# 1425
# dark, matter, top
# 1426
# melanoma, skin, compounds
# 1427
# echovirus, oncolytic, rigvir
# 1428
# gnss, sbas, dfmc
# 1429
# herbs, arsenic, inorganic
# 1430
# nanogel, disc, bone
# 1431
# bee, richness, bees
# 1432
# eastern, species, boonjarasii
# 1433
# orodental, pitx2, anomalies
# 1434
# electricity, liberalization, fdi
# 1435
# pois, dbscan, pick
# 1436
# aupd, nozzle, pdtio2
# 1437
# collaborative, project, selection
# 1438
# learning, flipped, classroom
# 1439
# mev, 018syst, mass
# 1440
# osa, bariatric, morbidly
# 1441
# topics, twitter, emerging
# 1442
# dna, c8, guanine
# 1443
# pituitary, ighd, height
# 1444
# 0μμ, proton, s8tev
# 1445
# cte, starch, flour
# 1446
# diesel, saturations, entrapped
# 1447
# health, care, uhc
# 1448
# dioxolane, 13, phb
# 1449
# chemistry, name, 101039c8nj01915k
# 1450
# afomp, australas, eng
# 1451
# zif, propane, propylene
# 1452
# fluoroalkylsilane, mesh, nrsio
# 1453
# p21, chk2, cytoplasmic
# 1454
# laminin, bcam, chain
# 1455
# disparities, gallbladder, racialethnic
# 1456
# cch, chitin, wound
# 1457
# finite, mohr, element
# 1458
# caterpillars, stinging, setae
# 1459
# mcrs, component, thc
# 1460
# airline, cockpit, crew
# 1461
# tetracycline, acnes, aureus
# 1462
# cbov, th, canine
# 1463
# sponge, nanocellulose, oil
# 1464
# attitude, workers, hcwm
# 1465
# letter, advantage, orthography
# 1466
# classification, techniques, classifiers
# 1467
# pile, barrette, piles
# 1468
# osteoporosis, tnfsf11, snp
# 1469
# cbct, work, 00
# 1470
# resonances, quarks, jet
# 1471
# punishment, motor, sensitivity
# 1472
# arsenate, adsorption, iron
# 1473
# epicatechins, catechins, tea
# 1474
# diagnosis, 00, 000
# 1475
# indentation, elastic, surface
# 1476
# markets, convergence, prediction
# 1477
# pmtbrg1, juveniles, shrimp
# 1478
# dbt, breast, lesions
# 1479
# zrsio4, glass, basalt
# 1480
# program, sroi, investment
# 1481
# tsunami, damage, fragility
# 1482
# sugar, hydrolysis, sulfonated
# 1483
# drift, flux, void
# 1484
# diesel, microemulsion, engine
# 1485
# government, ogdam, assessment
# 1486
# leadership, school, shadows
# 1487
# metabolic, syndrome, antiretroviral
# 1488
# cyperenoic, osteoclast, acid
# 1489
# preface, 00, 000
# 1490
# harvesting, fluxes, n2o
# 1491
# fe2o3, alcohol, adsorbed
# 1492
# spces, thionine, peroxide
# 1493
# event, proton, boson
# 1494
# probiotics, cognitive, probiotic
# 1495
# btxa, cgrp, migraine
# 1496
# ctvt, cytomorphological, lymphocytic
# 1497
# plsx, lipid, overexpressing
# 1498
# executive, impairments, deficit
# 1499
# antihistamines, rhinosinusitis, treating
# 1500
# lca, lcia, lcsoft
# 1501
# commitment, affective, democrat
# 1502
# pcr, jc, lactic
# 1503
# osa, ablation, catheter
# 1504
# 302a, 3p, rankl
# 1505
# polygonumins, minus, compound
# 1506
# pba, copolyesters, ho
# 1507
# unintended, pregnancy, literacy
# 1508
# scwg, kg100kgfeed, syngas
# 1509
# mets, ckd, obesity
# 1510
# yom, channel, flows
# 1511
# stachyobium, dendrobium, species
# 1512
# lime, juice, fresh
# 1513
# artifact, teeth, intensity
# 1514
# aging, hours, reheat
# 1515
# heparin, bridging, esd
# 1516
# isoflavonoids, isoflavonoid, suspension
# 1517
# variant, classical, pedv
# 1518
# regulation, stacked, frequency
# 1519
# sugar, ionic, pretreatment
# 1520
# mode, common, voltage
# 1521
# stabilization, nanofibers, fiber
# 1522
# shs, ppw, postpartum
# 1523
# jets, transverse, lepton
# 1524
# ldl, group, mortality
# 1525
# floods, recovery, narratives
# 1526
# homotopy, burgers, approximate
# 1527
# taxis, ngv, lpg
# 1528
# definable, set, zero
# 1529
# symphysis, abt, mandibular
# 1530
# tumors, mass, gelc
# 1531
# blood, pad, abo
# 1532
# probabilistic, algorithm, grammar
# 1533
# tio2, dxrd, m2g
# 1534
# campus, outdoor, cooling
# 1535
# octa, glaucoma, angiography
# 1536
# schools, secondary, education
# 1537
# adv, belisa, fluid
# 1538
# colistin, beta, resistance
# 1539
# chimes, mlc601, stroke
# 1540
# brucellosis, deer, farm
# 1541
# hiit, supra, preadolescent
# 1542
# phb, laminin, neuro2a
# 1543
# sleep, eds, referred
# 1544
# ordinating, suspected, district
# 1545
# chp, ha, nanoha
# 1546
# camsap3, microtubules, tubulin
# 1547
# spacetimes, superintegrable, resonant
# 1548
# avr, su, thrombocytopenia
# 1549
# aneurysm, tuberculous, aortic
# 1550
# bat, borne, respondents
# 1551
# pmu, frequency, synchronized
# 1552
# organophosphate, gqds, photoluminescence
# 1553
# tyrosinase, protease, dug
# 1554
# chitosan, oligosaccharides, degraded
# 1555
# rice, husked, bioaccessible
# 1556
# mi, cpt, atelectasis
# 1557
# proteins, palmivora, rs1
# 1558
# ars, ahi, art
# 1559
# al2o3, doped, azo
# 1560
# sludge, brewery, wastewater
# 1561
# tool, users, macaques
# 1562
# parviflora, tlc, dimethoxyflavone
# 1563
# ipcs, foam, resin
# 1564
# scma, stbc, mimo
# 1565
# groundwater, plain, 2km
# 1566
# asr, cancer, cancers
# 1567
# intrusion, machine, detection
# 1568
# evaporites, 00, 000
# 1569
# sensation, energy, sound
# 1570
# constitutive, flow, equations
# 1571
# 41gac, asiii, removal
# 1572
# cbct, dose, μsv
# 1573
# sleep, awakening, insomnia
# 1574
# hparr, mrd, chop
# 1575
# grafted, film, tio2
# 1576
# ceriporia, lacerata, inflata
# 1577
# mdht, fry, tilapia
# 1578
# shaft, refrigeration, condenser
# 1579
# glycolide, dex, lactide
# 1580
# tev, bosons, decaying
# 1581
# xenoliths, type, ruby
# 1582
# kidyoo, phuluangensis, corolla
# 1583
# transplantation, liver, hbs
# 1584
# photon, proton, quark
# 1585
# adcigs, migration, velocity
# 1586
# co2, caoc, gasifying
# 1587
# mangostin, cs, inclusion
# 1588
# poml, lymphoma, radiotherapy
# 1589
# oil, surfactant, pes
# 1590
# asphalt, hma, mixture
# 1591
# qdh, gluconobacter, quinate
# 1592
# learning, virtual, classroom
# 1593
# biodiesel, scgs, isopropanol
# 1594
# erythematosus, lupus, systemic
# 1595
# traffic, injury, senior
# 1596
# metformin, pancreatic, systemic
# 1597
# alternan, lcalt, lc
# 1598
# pparα, mammary, pparγ
# 1599
# ...
# 22159
# compelling, necessity, decade
# 22160
# genoa, milan, unification
# 22161
# canadian, universities, integrity
# 22162
# deans, interpretive, am
# 22163
# supportiveness, appreciation, undergraduate
# 22164
# disentangling, accent, competence
# 22165
# decanal, search, canadian
# 22166
# baubau, kinship, politics
# 22167
# multinational, companies, cultural
# 22168
# leadership, gender, style
# 22169
# happiness, hope, tourism
# 22170
# psychology, positive, tourism
# 22171
# enlightenment, heritage, tourism
# 22172
# preface, 00, 000
# 22173
# navigating, restorative, tourism
# 22174
# conclusion, 00, 000
# 22175
# canoe, wilderness, solo
# 22176
# tales, familiar, happiness
# 22177
# retreating, subjective, being
# 22178
# meaning, tourism, search
# 22179
# ruralscape, materialism, valuing
# 22180
# psychology, travel, being
# 22181
# happiness, volunteer, hope
# 22182
# carnival, joie, vivre
# 22183
# reflection, acceleration, introduction
# 22184
# peace, palestine, hope
# 22185
# tower, elliptic, embedding
# 22186
# narration, surnames, poles
# 22187
# bicycles, fault, sharing
# 22188
# astronomy, gamma, ray
# 22189
# astro, libraries, monte
# 22190
# keynote, atlas, data
# 22191
# iacts, estimation, event
# 22192
# physics, particle, 00
# 22193
# headroom, geometric, building
# 22194
# astroparticle, physics, particle
# 22195
# tau, neutrino, selection
# 22196
# corsika, learning, active
# 22197
# deconvolution, likelihood, based
# 22198
# icecube, event, selection
# 22199
# neutrino, muon, selection
# 22200
# lhcb, acquisition, data
# 22201
# keynote, inverse, introduction
# 22202
# brands, familiar, erp
# 22203
# mismatches, simulated, observed
# 22204
# concepts, machine, learning
# 22205
# introduction, deep, learning
# 22206
# astronomy, pipeline, gamma
# 22207
# iacts, structures, data
# 22208
# introduction, estimation, event
# 22209
# minutes, 00, 000
# 22210
# impiety, pious, sinning
# 22211
# 15supthsup, 8supthsup, milky
# 22212
# izala, muhammadiyah, salafism
# 22213
# aleksander, bediüzzaman, nursi
# 22214
# scholarship, psychology, reflections
# 22215
# 3d, flexible, electrodes
# 22216
# orthopedic, plates, additive
# 22217
# sentence, french, written
# 22218
# handwritten, grammatical, letters
# 22219
# hangeul, thaana, syllables
# 22220
# alexithymia, perfectionism, vitiligo
# 22221
# malacca, lethality, brine
# 22222
# encyclicals, paul, message
# 22223
# additive, axis, manufacturing
# 22224
# moose, poland, eastern
# 22225
# cundinamarca, colombia, peasant
# 22226
# aquaria, eri, carpio
# 22227
# epistemic, vocabulary, contextual
# 22228
# complexities, conducting, practices
# 22229
# pblpjbl, nursing, education
# 22230
# scoping, review, project
# 22231
# intime, interactional, mentor
# 22232
# schisis, coloboma, macular
# 22233
# concircular, sasakian, curvature
# 22234
# piecewise, argument, constant
# 22235
# fibonacci, identities, fuzzy
# 22236
# quadruple, operator, spaces
# 22237
# esup3sup, tubular, focal
# 22238
# vranceanu, bianchi, cartan
# 22239
# topological, closure, operator
# 22240
# shehu, laplace, transform
# 22241
# airlines, learning, opinion
# 22242
# soliton, ricci, sasakian
# 22243
# zakharov, conservative, schemes
# 22244
# integers, odd, integer
# 22245
# face, polynomials, identities
# 22246
# abcrule, convolutional, lesion
# 22247
# probabilistic, relation, revisiting
# 22248
# calculus, attractor, lorenz
# 22249
# pseudoparallel, submanifolds, sasakian
# 22250
# exponential, integral, fourth
# 22251
# riemannian, endowed, submanifolds
# 22252
# flc, polynomial, frame
# 22253
# kudryashov, sinelshchikov, neglecting
# 22254
# ophthalmomyiasis, externa, 00
# 22255
# lorentzian, curvatures, submanifolds
# 22256
# kirchhoff, nonlinearity, nonlocal
# 22257
# manypoint, singularities, discontinuous
# 22258
# coats, deposits, crystalline
# 22259
# metric, fuzzy, fixed
# 22260
# countable, nonexpansive, banach
# 22261
# pursuit, guaranteed, players
# 22262
# interpolative, kannan, mappings
# 22263
# linguistics, educational, theory
# 22264
# language, exploring, education
# 22265
# editors, note, 00
# 22266
# halliday, michael, language
# 22267
# linguistics, educational, concept
# 22268
# editorial, 00, 000
# 22269
# apostolorum, areopagus, laudatio
# 22270
# introduction, 00, 000
# 22271
# logistics, technological, aspects
# 22272
# afect, schematic, schema
# 22273
# implicitness, irony, echo
# 22274
# intercultural, norm, temporary
# 22275
# peruvian, pragmatic, lexical
# 22276
# unconstrained, conjugate, gradient
# 22277
# autism, intensive, spectrum
# 22278
# intercity, logistics, flows
# 22279
# incidental, logistics, multimodal
# 22280
# interaction, enterprise, partners
# 22281
# transportation, freight, customs
# 22282
# slavic, postcolonial, intersections
# 22283
# emigration, russian, italy
# 22284
# symbolism, russian, 1994
# 22285
# larantuka, flores, negeri
# 22286
# kopački, naturavita, rit
# 22287
# bednja, ipta, river
# 22288
# croatia, republic, overview
# 22289
# authenticity, understandings, multiplicity
# 22290
# estonian, rumors, tartu
# 22291
# wartime, ukrainian, butterfly
# 22292
# soccer, positional, players
# 22293
# footballers, hamstring, quadriceps
# 22294
# trained, daily, syndrome
# 22295
# coordination, bimanual, attentional
# 22296
# pepe, backpack, schoolchildren
# 22297
# tennis, you, sport
# 22298
# madrid, motives, reflections
# 22299
# countermovement, creatine, jump
# 22300
# likes, motivation, school
# 22301
# logic, mind, immune
# 22302
# homarus, panulirus, rflp
# 22303
# ngc, photoionization, 6572
# 22304
# kalumpang, karama, lariang
# 22305
# photoluminescence, casup2sup, nainf2inftisioinf5inf
# 22306
# tanggamus, granitoid, regency
# 22307
# ideologies, tangible, traces
# 22308
# speaker, pronunciation, french
# 22309
# doxic, multilingualism, speaking
# 22310
# morphosyllabic, learners, morphological
# 22311
# ander, elck, maar
# 22312
# speak, educated, brussels
# 22313
# looking, belgian, 1986
# 22314
# deharveng, etgrammaticale, philologique
# 22315
# simulacra, surimono, gatherings
# 22316
# rome, dresden, filippo
# 22317
# printmaking, vicente, accommodating
# 22318
# levantine, marseille, connoisseurship
# 22319
# fragonards, véri, marquis
# 22320
# globalizing, geopolitics, asymmetries
# 22321
# connoisseurship, eighteenth, europe
# 22322
# augusts, gotha, duke
# 22323
# antiquities, naples, resurfacing
# 22324
# connoisseurship, eighteenth, networked
# 22325
# crouching, radha, toilette
# 22326
# connoisseurship, eighteenth, century
# 22327
# anecdotes, repairers, reflections
# 22328
# detritus, portraits, roadside
# 22329
# cosmotechnics, repairing, soils
# 22330
# repair, restart, barcelona
# 22331
# designrepair, roundtable, discussion
# 22332
# skilling, at, youth
# 22333
# australias, obsolescence, inquiry
# 22334
# ethic, circularity, relational
# 22335
# othering, travelogues, differentiations
# 22336
# worthwhileness, norway, contributions
# 22337
# kampus, mbkm, merdeka
# 22338
# manufactured, dental, technologies
# 22339
# basketball, ball, players
# 22340
# introduction, 00, 000
# 22341
# preface, 00, 000
# 22342
# foundations, prospects, europe
# 22343
# economie, ford, sociale
# 22344
# portugal, regime, legal
# 22345
# convergences, divergences, spanish
# 22346
# taxation, entities, law
# 22347
# netherlands, legal, infrastructure
# 22348
# foreword, 00, 000
# 22349
# backyard, pakistani, enterica
# 22350
# third, poland, republic
# 22351
# lionization, scandal, speak
# 22352
# rhetorical, hero, heroes
# 22353
# design, socially, literacy
# 22354
# unfulfilled, chilean, curricula
# 22355
# liberalization, ukraine, entrepreneurship
# 22356
# periagōgē, plato, aspect
# 22357
# ventricular, bidomain, contractions
# 22358
# radiomic, thrombus, ischemic
# 22359
# reassessing, chaos, writing
# 22360
# institutionalization, multicultural, religious
# 22361
# writing, systematic, nature
# 22362
# chiredzi, resettled, unpackaging
# 22363
# process, indices, capability
# 22364
# labelling, naming, africa
# 22365
# dialectics, eswatini, commemorative
# 22366
# rhinology, reflection, conference
# 22367
# meniere, immunological, progress
# 22368
# reinnervation, laryngeal, vocal
# 22369
# brilliant, generation, write
# 22370
# joins, forging, uniting
# 22371
# apnea, obstructive, sleep
# 22372
# tinnitus, harnessing, therapeutics
# 22373
# ear, endoscopic, technology
# 22374
# chapters, 00, 000
# 22375
# laryngopharyngeal, reflux, advances
# 22376
# fatherly, guiyi, teachings
# 22377
# apnea, obstructive, sleep
# 22378
# retrospect, revolutions, prospect
# 22379
# hearing, directions, innovative
# 22380
# gazing, forging, blueprint
# 22381
# prospect, nasopharyngeal, carcinoma
# 22382
# sages, letter, words
# 22383
# my, reviving, elders
# 22384
# selflessness, otolaryngology, thoughts
# 22385
# otorhinolaryngology, neck, pediatric
# 22386
# artistic, presentation, scientific
# 22387
# intranasal, advancements, corticosteroids
# 22388
# marching, 70th, opportune
# 22389
# auditory, implantation, latest
# 22390
# blazing, congratulations, 70th
# 22391
# from, rhinosinusitis, advances
# 22392
# otological, progress, medicine
# 22393
# recalling, my, path
# 22394
# magazine, clinic, operation
# 22395
# standardization, voice, disorders
# 22396
# from, gene, hearing
# 22397
# freshman, lighthouse, doctor
# 22398
# neck, progress, head
# 22399
# półtorzecki, adam, judicial
# 22400
# legibus, publica, cicero
# 22401
# bulawayo, ndebele, purism
# 22402
# langila, playful, relabelling
# 22403
# bibliometric, networking, islamic
# 22404
# naming, meanings, entities
# 22405
# transparency, performances, 00
# 22406
# gins, craft, onomastic
# 22407
# kombis, harare, inscriptions
# 22408
# chameleonic, highlanders, nicknames
# 22409
# abugidas, alphasyllabaries, segmentaries
# 22410
# seeing, latin, double
# 22411
# koineization, pamphylian, alphabet
# 22412
# standardisation, spelling, said
# 22413
# formalized, expandable, proposal
# 22414
# dermatoglyphics, ibadan, southwest
# 22415
# language, proficiencies, linguistically
# 22416
# bulbar, muscular, atrophy
# 22417
# aktobe, oblast, geotourism
# 22418
# friuli, giulia, venezia
# 22419
# slovenia, atlas, disasters
# 22420
# burgenland, radkersburg, slovenian
# 22421
# republican, readers, turkey
# 22422
# buket, toprak, uzuners
# 22423
# diary, books, childrens
# 22424
# descent, conjugate, gradient
# 22425
# photoelectric, machinery, navigation
# 22426
# brianza, monza, territories
# 22427
# spirituality, jakarta, islamic
# 22428
# contrastive, proficiency, learners
# 22429
# academic, manufacturing, knowledge
# 22430
# listening, bottoms, pronunciation
# 22431
# criticality, impossible, infrastructures
# 22432
# prosody, gestures, sounds
# 22433
# prosody, pedagogy, studies
# 22434
# algorithmic, scientific, power
# 22435
# dialect, abroad, perceptual
# 22436
# ethnopoetic, poetry, gateway
# 22437
# peers, editors, journals
# 22438
# suprasegmental, pedagogy, teaching
# 22439
# german, teaching, perspectives
# 22440
# sait, hanyu, pronunciation
# 22441
# tutor, supra, prosody
# 22442
# intelligible, melodies, comprehensible
# 22443
# hanfu, discursive, spatiotemporal
# 22444
# romani, hungary, nineteenth
# 22445
# steps, forward, special
# 22446
# copycat, paradoxes, excellence
# 22447
# anthony, thalamic, ischaemic
# 22448
# shunting, transjugular, portosystemic
# 22449
# durban, inkosi, luthuli
# 22450
# intelligence, augmented, big
# 22451
# africas, pepfar, cape
# 22452
# lv3, rewriting, productions
# 22453
# fuency, lending, pitch
# 22454
# armorials, arthurian, busterins
# 22455
# object, infants, word
# 22456
# fables, medieval, ancient
# 22457
# another, voice, language
# 22458
# animalia, invisa, prius
# 22459
# bank, nbp, panyabungan
# 22460
# sports, foods, 00
# 22461
# doplang, alluvial, spt
# 22462
# mamuju, regency, dosimetry
# 22463
# euro, mediterranean, aspects
# 22464
# andalusian, centuryfifth, mulūk
# 22465
# fez, meknes, development
# 22466
# dataexploratorystudy, landsat8, sst
# 22467
# entrepreneur, mediterranean, career
# 22468
# prerequisite, egypt, inflation
# 22469
# intrapleural, closure, vacuum
# 22470
# zpms, aspirin, preeclampsia
# 22471
# writing, non, 00
# 22472
# religious, denial, prisons
# 22473
# ānīrī, sufi, ān
# 22474
# noah, ān, qur
# 22475
# wilāyah, ismā, īlī
# 22476
# bangladeshs, contextual, enteric
# 22477
# hydatid, retro, cyst
# 22478
# bangladesh, attitudes, perception
# 22479
# silymarin, nephrotoxicity, gentamicin
# 22480
# carbetocin, partum, caesarean
# 22481
# genital, narrative, tuberculosis
# 22482
# torrent, carbonation, permeability
# 22483
# caribaeorum, zoanthid, palythoa
# 22484
# rabinowitsch, squeeze, lubrication
# 22485
# hyperthermia, pelvic, segmentation
# 22486
# pinctada, pteriidae, imbricata
# 22487
# slag, paste, alkali
# 22488
# firefighting, extinguishing, repeatedly
# 22489
# multifunction, inverter, multilevel
# 22490
# castañeta, cichliformes, latifrons
# 22491
# monolingual, storytelling, bilingual
# 22492
# interpreting, cognition, aging
# 22493
# trackers, wearable, eye
# 22494
# indies, missionary, seventeenth
# 22495
# anachronistic, sībawayhi, ḥarf
# 22496
# deaf, gesture, parent
# 22497
# voice, reading, spans
# 22498
# monolingual, preschoolers, bilingual
# 22499
# contextualising, expertise, lived
# 22500
# reception, museum, cognition
# 22501
# frst, interpreting, translation
# 22502
# afroperspectivist, epistemes, bold
# 22503
# columnism, yesterday, varieties
# 22504
# ela, freire, hora
# 22505
# beauty, cromosmagazine, trivialization
# 22506
# chile, teams, discourse
# 22507
# alleviation, poverty, sharia
# 22508
# tanjungpinang, riau, customary
# 22509
# buying, cloud, marketing
# 22510
# vowel, contrasts, classroom
# 22511
# listening, speech, noise
# 22512
# french, teaching, perspectives
# 22513
# corpora, concordance, beyond
# 22514
# unanswered, pronunciation, instruction
# 22515
# ellipse, learner, proficiency
# 22516
# orthography, cognate, spanish
# 22517
# falou, moymer, 2022
# 22518
# japan, language, second
# 22519
# pop, interdisciplinary, language
# 22520
# automaticity, utterance, grammatical
# 22521
# efl, reading, adolescents
# 22522
# accented, segments, words
# 22523
# socialization, agency, language
# 22524
# japanese, zibun, reflexive
# 22525
# stylistics, pop, educational
# 22526
# songs, mental, health
# 22527
# speakers, noun, phrases
# 22528
# spain, rule, member
# 22529
# astronomy, language, 00
# 22530
# zoomland, humanities, exploring
# 22531
# abstractions, reflective, terminology
# 22532
# introduction, 00, 000
# 22533
# epikhartika, colonial, matters
# 22534
# animalium, aristotles, generatione
# 22535
# zooming, reframing, transnational
# 22536
# fractal, granularity, informational
# 22537
# diachronic, controversy, weather
# 22538
# zoom, sculptures, optics
# 22539
# traces, defining, mining
# 22540
# heterocycles, pharmaceutical, solvent
# 22541
# emancipated, documenting, scaling
# 22542
# menocchio, microhistory, italian
# 22543
# aesthetics, meaningful, tools
# 22544
# historicising, temporalities, virality
# 22545
# muellers, martin, literary
# 22546
# longform, conceiving, microhistory
# 22547
# lore, rhetoric, siege
# 22548
# graphpoem, iconicity, monstrosity
# 22549
# heterocycles, reusable, silica
# 22550
# nomenclature, naming, ancient
# 22551
# technologized, professionalism, terminology
# 22552
# sonic, ears, swedish
# 22553
# discourse, weimar, capturing
# 22554
# cartographic, zooming, generalisation
# 22555
# adventures, zoomland, storytelling
# 22556
# craugastor, frogs, overestimation
# 22557
# sparrow, hyperspectral, tomato
# 22558
# turbine, vehicle, electric
# 22559
# conceptualizing, linguistic, corpus
# 22560
# vtol, verification, electric
# 22561
# tamil, speakers, india
# 22562
# aggressiveness, asymmetric, trajectory
# 22563
# uavs, unmanned, certification
# 22564
# bezier, lane, swarm
# 22565
# departure, flight, delay
# 22566
# slung, quadrotor, swing
# 22567
# highway, merging, interactive
# 22568
# prophase, evtol, aircraft
# 22569
# actuator, electromagnetic, equipped
# 22570
# clutch, switching, continuously
# 22571
# vtol, landing, wing
# 22572
# lane, game, vehicles
# 22573
# shimmy, monorail, straddle
# 22574
# baggage, airport, scheduling
# 22575
# sliding, electromagnetic, vibration
# 22576
# magnetorheological, damper, relief
# 22577
# evtol, flight, architecture
# 22578
# mbsa, evtol, flight
# 22579
# surge, aircraft, engine
# 22580
# damper, damping, electromagnetic
# 22581
# grc, gat, fusing
# 22582
# underactuated, quadrotor, unmanned
# 22583
# evtol, landing, wing
# 22584
# cockpit, centric, ice
# 22585
# queue, dispersal, accidents
# 22586
# electric, propulsion, vtol
# 22587
# javanese, request, pragmatic
# 22588
# dqra, m2m, mimo
# 22589
# prandini, conflict, trajectory
# 22590
# mppt, uav, sliding
# 22591
# powertrain, vehicles, coastal
# 22592
# figurative, persian, conceptualization
# 22593
# iuam, sae, symposium
# 22594
# steering, game, road
# 22595
# td3, platooning, pid
# 22596
# cruise, adas, adaptive
# 22597
# gear, vibration, drive
# 22598
# switchable, regenerative, suspension
# 22599
# uav, flight, uncertainty
# 22600
# som, trajectory, intelligent
# 22601
# airworthiness, propulsion, evtol
# 22602
# aeroengine, lstm, path
# 22603
# aerodynamics, propulsion, evtol
# 22604
# 200kw, aviation, precision
# 22605
# '\'\'\n# Add the top two keywords to the dataframe\ndata["Top_Two_Keywords"] = top_two_keywords\n\n# Save the updated dataframe to a new CSV file\noutput_file = "data_with_top_two_keywords.csv"\ndata.to_csv(output_file, index=False)\n\nprint("Top two keywords extracted and saved to", output_file)\n'

# %%
# Add the top two keywords to the dataframe
data["Top_Three_Keywords"] = top_two_keywords
data.drop(columns=['Top_Two_Keywords'], inplace=True)

# Save the updated dataframe to a new CSV file
output_file = "merged_data_withkeywords.csv"
data.to_csv(output_file, index=False)

print("Top three keywords extracted and saved to", output_file)
# Out:
# Top three keywords extracted and saved to merged_data_withkeywords.csv

# %%
import pandas as pd
data = pd.read_csv('merged_data_withkeywords.csv')
def one(str):
  ls = str.split(',')
  return ls[0].strip()

data['One_keyword'] = data['Top_Three_Keywords'].apply(lambda x: one(x))
output_file = "merged_data_withkeywords.csv"
data.to_csv(output_file, index=False)

print("One keywords extracted and saved to", output_file)
# Out:
# One keywords extracted and saved to merged_data_withkeywords.csv
