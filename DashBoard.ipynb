# %%
import streamlit as st
import pandas as pd

# Load or create your dataset
data = {
    "Subject Area": ["AI", "AI", "AI", "ML", "ML", "Data Science", "Data Science"],
    "Year": [2020, 2021, 2022, 2020, 2021, 2020, 2021],
    "Trending Keywords": [
        ["neural networks", "deep learning"],
        ["transformers", "reinforcement learning"],
        ["AI ethics", "generative models"],
        ["supervised learning", "SVM"],
        ["unsupervised learning", "clustering"],
        ["data visualization", "Pandas"],
        ["big data", "Python"]
    ]
}
df = pd.DataFrame(data)

# Streamlit elements
st.title("Keyword Trends Dashboard")

# Subject area selector
subject_area = st.selectbox("Select Subject Area", df["Subject Area"].unique())

# Year selector
year = st.selectbox("Select Year", df["Year"].unique())

# Filter data based on selection
filtered_data = df[(df["Subject Area"] == subject_area) & (df["Year"] == year)]

if filtered_data.empty:
    st.write(f"No data available for {subject_area} in {year}")
else:
    st.write(f"Trending Keywords in {subject_area} for {year}:")
    st.write(filtered_data["Trending Keywords"].values[0])
# Out:
# 2024-12-06 17:57:59.612 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.712
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/fay/Library/Python/3.12/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-12-06 17:57:59.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.717 Session state does not function when running a script without `streamlit run`
# 2024-12-06 17:57:59.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-06 17:57:59.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
def slicing(date):
  l = date.split('/')
  return l[-1]
df['publication_date_year'] = df['publication_date'].apply(lambda x:slicing(x))
df.groupby('publication_date_year')['subjectArea'].describe()
df_2018 = df.loc[df['publication_date_year'] == '2018']
x = df_2018['subjectArea'].value_counts().reset_index()
x
# Out:
#              subjectArea  count
# 0                   MEDI    434
# 1                   PHYS    175
# 2                   COMP     86
# 3              MATE,ENGI     82
# 4                   AGRI     81
# ..                   ...    ...
# 293            COMP,BIOC      1
# 294  PHYS,EART,COMP,ENGI      1
# 295            CENG,BIOC      1
# 296       CENG,AGRI,ENGI      1
# 297       CENG,CHEM,BIOC      1
#
# [298 rows x 2 columns]

# %%
df
# Out:
#                                                    title  \
# 0      Effects of iron content on the microstructure ...
# 1      The critical factors of research and innovatio...
# 2      Is the occiput-wall distance valid and reliabl...
# 3      Comparison of soil composition between farmlan...
# 4      The impact of wire caliber on ERCP outcomes: a...
# ...                                                  ...
# 20211  A Techno-Economic Assessment of a Second-Life ...
# 20212  Encouraging green product purchase: Green valu...
# 20213  Does leukocytosis remain a predictive factor f...
# 20214  Administration of ketoprofen in postpartum sow...
# 20215  Role of Anxiety in Willingness to Communicate ...
#
#                                          publicationName  \
# 0                        Materials Chemistry and Physics
# 1      International Journal of Trade and Global Markets
# 2                   Musculoskeletal Science and Practice
# 3               Eurasian Journal of Analytical Chemistry
# 4                             Gastrointestinal Endoscopy
# ...                                                  ...
# 20211                       Sustainability (Switzerland)
# 20212              Business Strategy and the Environment
# 20213                        Hematology (United Kingdom)
# 20214                                  Animal Bioscience
# 20215              3L: Language, Linguistics, Literature
#
#                                                 abstract  \
# 0      © 2018The microstructure and corrosion behavio...
# 1      Copyright © 2018 Inderscience Enterprises Ltd....
# 2      © 2018Background: Hyperkyphosis may be frequen...
# 3      © 2018 Society for Innovative Research. All ri...
# 4      © 2018Background and Aims: Wire-guided biliary...
# ...                                                  ...
# 20211  © 2023 by the authors.This study discusses the...
# 20212  © 2022 ERP Environment and John Wiley & Sons L...
# 20213  © 2023 The Author(s). Published by Informa UK ...
# 20214  © 2023 by Animal Bioscience.Objective: Inflamm...
# 20215  © 2023 Penerbit Universiti Kebangsaan Malaysia...
#
#                                                 keywords  \
# 0      EIS,Microstructure,Pitting corrosion,Polarizat...
# 1      Critical factors,Innovation creation,Public un...
# 2             Cobb angle,Dowager's hump,Round back,Spine
# 3      Agriculture land management,Conserved area,Soi...
# 4                                                    NaN
# ...                                                  ...
# 20211  battery degradation,electric vehicle charging,...
# 20212  attitude–behavior gap,environmental knowledge,...
# 20213          Acute promyelocytic leukemia,APL,Thailand
# 20214  Colostrum,Inflammation,Ketoprofen,Lactational Pig
# 20215  anxiety,cultural beliefs,fear of committing er...
#
#                     subjectArea publication_date publication_date_year
# 0                     MATE,PHYS       01/10/2018                  2018
# 1                     BUSI,ECON       01/01/2018                  2018
# 2                          HEAL       01/12/2018                  2018
# 3                     PHAR,CHEM       01/01/2018                  2018
# 4                          MEDI       01/06/2018                  2018
# ...                         ...              ...                   ...
# 20211  ENVI,SOCI,ENER,ENGI,COMP       01/04/2023                  2023
# 20212            ENVI,SOCI,BUSI       01/01/2023                  2023
# 20213                      MEDI       01/01/2023                  2023
# 20214            VETE,AGRI,BIOC       01/08/2023                  2023
# 20215                 SOCI,ARTS       01/01/2023                  2023
#
# [20216 rows x 7 columns]
