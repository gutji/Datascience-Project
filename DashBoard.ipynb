# %%
import streamlit as st
import pandas as pd

# Load or create your dataset
data = {
    "Subject Area": ["AI", "AI", "AI", "ML", "ML", "Data Science", "Data Science"],
    "Year": [2020, 2021, 2022, 2020, 2021, 2020, 2021],
    "Trending Keywords": [
        ["neural networks", "deep learning"],
        ["transformers", "reinforcement learning"],
        ["AI ethics", "generative models"],
        ["supervised learning", "SVM"],
        ["unsupervised learning", "clustering"],
        ["data visualization", "Pandas"],
        ["big data", "Python"]
    ]
}
df = pd.DataFrame(data)

# Streamlit elements
st.title("Keyword Trends Dashboard")

# Subject area selector
subject_area = st.selectbox("Select Subject Area", df["Subject Area"].unique())

# Year selector
year = st.selectbox("Select Year", df["Year"].unique())

# Filter data based on selection
filtered_data = df[(df["Subject Area"] == subject_area) & (df["Year"] == year)]

if filtered_data.empty:
    st.write(f"No data available for {subject_area} in {year}")
else:
    st.write(f"Trending Keywords in {subject_area} for {year}:")
    st.write(filtered_data["Trending Keywords"].values[0])

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
def slicing(date):
  l = date.split('/')
  return l[-1]
df['publication_date_year'] = df['publication_date'].apply(lambda x:slicing(x))
df.groupby('publication_date_year')['subjectArea'].describe()
df_2018 = df.loc[df['publication_date_year'] == '2018']
x = df_2018['subjectArea'].value_counts().reset_index()
x
# Out:
#    subjectArea  count
# 0         MEDI    448
# 1         BIOC    162
# 2         CHEM    155
# 3         COMP    148
# 4         MATE    148
# 5         PHYS    139
# 6         AGRI    129
# 7         ENGI    126
# 8         ENVI     81
# 9         IMMU     78
# 10        PHAR     75
# 11        CENG     70
# 12        SOCI     66
# 13        VETE     63
# 14        ENER     50
# 15        BUSI     44
# 16        NEUR     43
# 17        EART     34
# 18        MATH     30
# 19        DENT     30
# 20        MULT     28
# 21        NURS     19
# 22        PSYC     16
# 23        HEAL     15
# 24        ECON     13
# 25        ARTS     10
# 26        DECI      3

# %%
df
# Out:
#        Unnamed: 0                                              title  \
# 0               0  Effects of iron content on the microstructure ...
# 1               1  The critical factors of research and innovatio...
# 2               2  Is the occiput-wall distance valid and reliabl...
# 3               3  Comparison of soil composition between farmlan...
# 4               5  The influence of neighbor effect and urbanizat...
# ...           ...                                                ...
# 16314       20211  A Techno-Economic Assessment of a Second-Life ...
# 16315       20212  Encouraging green product purchase: Green valu...
# 16316       20213  Does leukocytosis remain a predictive factor f...
# 16317       20214  Administration of ketoprofen in postpartum sow...
# 16318       20215  Role of Anxiety in Willingness to Communicate ...
#
#                                          publicationName  \
# 0                        Materials Chemistry and Physics
# 1      International Journal of Trade and Global Markets
# 2                   Musculoskeletal Science and Practice
# 3               Eurasian Journal of Analytical Chemistry
# 4                            Progress in Transplantation
# ...                                                  ...
# 16314                       Sustainability (Switzerland)
# 16315              Business Strategy and the Environment
# 16316                        Hematology (United Kingdom)
# 16317                                  Animal Bioscience
# 16318              3L: Language, Linguistics, Literature
#
#                                                 abstract  \
# 0      microstructure corrosion behavior hot rolled t...
# 1      copyright   inderscience enterprises ltd. univ...
# 2      background hyperkyphosis frequently found nowa...
# 3        society innovative research rights reserved ...
# 4      natco rights reserved introduction population ...
# ...                                                  ...
# 16314    authors study discusses use retired battery ...
# 16315    erp environment john wiley sons ltd. green p...
# 16316    author(s published informa uk limited tradin...
# 16317    animal bioscience objective inflammation pai...
# 16318    penerbit universiti kebangsaan malaysia righ...
#
#                                                 keywords subjectArea  \
# 0      EIS Microstructure Pitting corrosion Polarizat...        MATE
# 1      Critical factors Innovation creation Public un...        BUSI
# 2             Cobb angle Dowager's hump Round back Spine        HEAL
# 3      Agriculture land management Conserved area Soi...        CHEM
# 4      Choice Consumer wellness Decision-making Neigh...        MEDI
# ...                                                  ...         ...
# 16314  battery degradation electric vehicle charging ...        COMP
# 16315  attitude–behavior gap environmental knowledge ...        BUSI
# 16316          Acute promyelocytic leukemia APL Thailand        MEDI
# 16317  Colostrum Inflammation Ketoprofen Lactational Pig        AGRI
# 16318  anxiety cultural beliefs fear of committing er...        ARTS
#
#       publication_date publication_date_year
# 0           01/10/2018                  2018
# 1           01/01/2018                  2018
# 2           01/12/2018                  2018
# 3           01/01/2018                  2018
# 4           01/03/2018                  2018
# ...                ...                   ...
# 16314       01/04/2023                  2023
# 16315       01/01/2023                  2023
# 16316       01/01/2023                  2023
# 16317       01/08/2023                  2023
# 16318       01/01/2023                  2023
#
# [16319 rows x 8 columns]
