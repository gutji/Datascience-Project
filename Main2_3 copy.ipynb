# %%
import os
import json
import pandas as pd

# Directories containing JSON files
directories = ['2018','2019','2020','2021','2022','2023']

# List to store extracted data
extracted_data = []

# Iterate through each directory
for directory in directories:
    # Iterate through each file in the current directory
    for filename in os.listdir(directory):
        if filename.endswith('.json'):  # Ensure it's a JSON file
            filepath = os.path.join(directory, filename)
            
            # Open and load the JSON file
            with open(filepath, 'r', encoding="utf-8") as file:
                data = json.load(file)
                
                # Extract the relevant part of the JSON
                response = data.get('abstracts-retrieval-response', {})
                
                # Extract specific fields
                title = response.get('coredata', {}).get('dc:title', None)
                publicationName = response.get('coredata', {}).get('prism:publicationName', None)
                abstract = response.get('item', {}).get('bibrecord', {}).get('head', {}).get('abstracts', None)
                
                subject_area_list = response.get('subject-areas', {}).get('subject-area', [])
                subjectArea = [item.get('@abbrev', None) for item in subject_area_list if '@abbrev' in item]

                # publication date
                date = response.get('item', {}).get("ait:process-info", {}).get("ait:date-sort",{})
                day = date.get("@day")
                year = date.get("@year")
                month = date.get('@month')
                format_date = f"{day}/{month}/{year}"

                # Extract author keywords and combine into a single string
                # Extract author keywords and combine into a single string
                auth_keywords = response.get('authkeywords', {})
                if isinstance(auth_keywords, dict):  # Ensure it's a dictionary
                    keywords_list = auth_keywords.get('author-keyword', [])
                    if isinstance(keywords_list, list):  # Ensure 'author-keyword' is a list
                        combined_keywords = " ".join(
                        [kw.get('$', '') for kw in keywords_list if isinstance(kw, dict)]
                        )
                else:
                    combined_keywords = None  # Handle cases where auth_keywords is not a dictionary

                # Append the extracted data as a dictionary
                extracted_data.append({
                    'title': title,
                    'publicationName': publicationName,
                    'abstract' : abstract,
                    'keywords': combined_keywords,
                    'subjectArea': subjectArea,
                    'publication_date': format_date
                })

# Convert the extracted data into a DataFrame
df = pd.DataFrame(extracted_data)
def change(x):
        x=  set(x)
        result = ""
        for area in x:
            result += area + ","

        return result[:-1]
df["subjectArea"] = df["subjectArea"].apply(change)

# %%
df
# Out:
#                                                    title  \
# 0      Effects of iron content on the microstructure ...
# 1      The critical factors of research and innovatio...
# 2      Is the occiput-wall distance valid and reliabl...
# 3      Comparison of soil composition between farmlan...
# 5      The influence of neighbor effect and urbanizat...
# ...                                                  ...
# 20211  A Techno-Economic Assessment of a Second-Life ...
# 20212  Encouraging green product purchase: Green valu...
# 20213  Does leukocytosis remain a predictive factor f...
# 20214  Administration of ketoprofen in postpartum sow...
# 20215  Role of Anxiety in Willingness to Communicate ...
#
#                                          publicationName  \
# 0                        Materials Chemistry and Physics
# 1      International Journal of Trade and Global Markets
# 2                   Musculoskeletal Science and Practice
# 3               Eurasian Journal of Analytical Chemistry
# 5                            Progress in Transplantation
# ...                                                  ...
# 20211                       Sustainability (Switzerland)
# 20212              Business Strategy and the Environment
# 20213                        Hematology (United Kingdom)
# 20214                                  Animal Bioscience
# 20215              3L: Language, Linguistics, Literature
#
#                                                 abstract  \
# 0      © 2018The microstructure and corrosion behavio...
# 1      Copyright © 2018 Inderscience Enterprises Ltd....
# 2      © 2018Background: Hyperkyphosis may be frequen...
# 3      © 2018 Society for Innovative Research. All ri...
# 5      © 2017, NATCO. All rights reserved.Introductio...
# ...                                                  ...
# 20211  © 2023 by the authors.This study discusses the...
# 20212  © 2022 ERP Environment and John Wiley & Sons L...
# 20213  © 2023 The Author(s). Published by Informa UK ...
# 20214  © 2023 by Animal Bioscience.Objective: Inflamm...
# 20215  © 2023 Penerbit Universiti Kebangsaan Malaysia...
#
#                                                 keywords  \
# 0      EIS Microstructure Pitting corrosion Polarizat...
# 1      Critical factors Innovation creation Public un...
# 2             Cobb angle Dowager's hump Round back Spine
# 3      Agriculture land management Conserved area Soi...
# 5      Choice Consumer wellness Decision-making Neigh...
# ...                                                  ...
# 20211  battery degradation electric vehicle charging ...
# 20212  attitude–behavior gap environmental knowledge ...
# 20213          Acute promyelocytic leukemia APL Thailand
# 20214  Colostrum Inflammation Ketoprofen Lactational Pig
# 20215  anxiety cultural beliefs fear of committing er...
#
#                     subjectArea publication_date
# 0                     PHYS,MATE       01/10/2018
# 1                     BUSI,ECON       01/01/2018
# 2                          HEAL       01/12/2018
# 3                     CHEM,PHAR       01/01/2018
# 5                          MEDI       01/03/2018
# ...                         ...              ...
# 20211  ENER,ENVI,COMP,ENGI,SOCI       01/04/2023
# 20212            BUSI,ENVI,SOCI       01/01/2023
# 20213                      MEDI       01/01/2023
# 20214            VETE,BIOC,AGRI       01/08/2023
# 20215                 ARTS,SOCI       01/01/2023
#
# [16319 rows x 6 columns]

# %%
df.dropna(inplace=True) #axis=0

# %%
df.shape
# Out:
# (16319, 6)

# %% [markdown]
# Clean Abstract

# %%
import spacy
print(spacy.__version__)
# Out:
# 3.8.2

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import re

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to clean abstract text
def clean_abstract(abstract):
    # Remove copyright symbols and years (like "© 2019")
    abstract = re.sub(r'©\s*\d{4}', '', abstract)
    doc = nlp(abstract)
    cleaned_text = " ".join([token.text.lower() for token in doc if not token.is_stop and not token.is_punct and not token.is_digit])

    return cleaned_text

# Example abstract
abstract = "© 2019 2019 Aungsuroch et al., published by Sciendo. There is no single study that has examined nursing research priorities in Vietnam..."

# Clean the abstract
cleaned_abstract = clean_abstract(abstract)

# Output cleaned abstract
print(cleaned_abstract)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[34], line 6
#       3 import re
#       5 # Load spaCy English model
# ----> 6 nlp = spacy.load("en_core_web_sm")
#       8 # Function to clean abstract text
#       9 def clean_abstract(abstract):
#      10     # Remove copyright symbols and years (like "© 2019")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/spacy/util.py:472, in load_model(name, vocab, disable, enable, exclude, config)
#     470 if name in OLD_MODEL_SHORTCUTS:
#     471     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 472 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %%
df['abstract_cleaned'] = [clean_abstract(a) for a in df['abstract'].to_list()]

# %%
df['abstract_cleaned'] = df['abstract_cleaned'].str.replace(r'\bieee.\b', '', regex=True)
df['abstract'] = df['abstract_cleaned']
df.drop(columns=['abstract_cleaned'], inplace=True)
df.head()
# Out:
#                                                title  \
# 2  Parametric study of hydrogen production via so...
# 3  Superhydrophobic coating from fluoroalkylsilan...
# 4  Electrochemical impedance-based DNA sensor usi...
# 5  Evaluation of outsourcing transportation contr...
# 6  The phenotypic and mutational spectrum of Thai...
#
#                         publicationName  \
# 2          Chemical Engineering Science
# 3               Applied Surface Science
# 4                Analytica Chimica Acta
# 5  Polish Journal of Management Studies
# 6                                  Gene
#
#                                             abstract  \
# 2    elsevier ltdcomputational fluid dynamics app...
# 3    elsevier b.v. superhydrophobic superoleophil...
# 4    elsevier b.v. label free electrochemical dna...
# 5  czestochowa university technology rights reser...
# 6    elsevier b.v.ornithine transcarbamylase defi...
#
#                                             keywords subjectArea  \
# 2  Circulating fluidized bed Computational fluid ...        CHEM
# 3  Encapsulation Fluoroalkylsilane Natural rubber...        CHEM
# 4  acpcPNA Electrochemical impedance spectroscopy...        CHEM
# 5  Design of experiment Optimal fleet size Outsou...        BUSI
# 6  Female Hyperammonemia Novel mutations Ornithin...        BIOC
#
#   publication_date
# 2       31/12/2018
# 3       31/12/2018
# 4       31/12/2018
# 5       30/12/2018
# 6       30/12/2018

# %%
# Save DataFrame as a CSV file
df.to_csv('output.csv', index=True)

# %%
df.groupby('subjectArea').describe()
# Out:
#             title                                                            \
#             count unique                                                top
# subjectArea
# AGRI          899    899  Penicillium Imranianum, a new species from the...
# ARTS          171    171  The long reach of English law: A case of incid...
# BIOC          934    933  The effects of beliefs, knowledge, and attitud...
# BUSI          280    280  The critical factors of research and innovatio...
# CENG          581    581  Fibrous platelet carbon nanofibers-silica fibe...
# CHEM          825    825  Comparison of soil composition between farmlan...
# COMP          870    869  Deep multispectral painting reproduction via m...
# DECI           17     17  BEstream: Batch Capturing with Elliptic Functi...
# DENT          233    233  Pediatric cleft palate patients show a 3- to 5...
# EART          183    183  Acid volatile sulphide estimation using spatia...
# ECON          104    104  The impact of financial and trade integration ...
# ENER          391    391  Analysis of a solid oxide fuel cell and a molt...
# ENGI          748    747  Axial load-strain relationships of partially e...
# ENVI          529    529  Synergistic degradation of pyrene by five cult...
# HEAL          119    119  Is the occiput-wall distance valid and reliabl...
# IMMU          437    437  A cytosolic sensor, PmDDX41, mediates antivira...
# MATE          678    677  Structure and mechanical properties of ADC 12 ...
# MATH          208    208  Half-normal approximation for statistics of sy...
# MEDI         2839   2837  2020 APHRS/HRS expert consensus statement on t...
# MULT          264    264  Modelling and electrical characteristics of th...
# NEUR          214    214  Zika Virus as an Emerging Neuropathogen: Mecha...
# NURS          115    115  Temporal Trends Between 2010 and 2015 in Inten...
# PHAR          374    374  A novel flavanone derivative inhibits dengue v...
# PHYS          508    508  Effect of gamma irradiation on properties of u...
# PSYC          130    130  I'll get there because I'm great, or am I? Nar...
# SOCI          623    623  Design and development of SECI and moodle onli...
# VETE          295    295  Monitoring and controlling ovarian activity in...
#
#                  publicationName         \
#             freq           count unique
# subjectArea
# AGRI           1             899    289
# ARTS           1             171     63
# BIOC           2             934    323
# BUSI           1             280    146
# CENG           1             581    101
# CHEM           1             825    159
# COMP           2             870    277
# DECI           1              17     12
# DENT           1             233     70
# EART           1             183     79
# ECON           1             104     62
# ENER           1             391     82
# ENGI           2             748    250
# ENVI           1             529    146
# HEAL           1             119     51
# IMMU           1             437    108
# MATE           2             678    165
# MATH           1             208    103
# MEDI           2            2839   1045
# MULT           1             264     24
# NEUR           1             214     63
# NURS           1             115     54
# PHAR           1             374    108
# PHYS           1             508     90
# PSYC           1             130     64
# SOCI           1             623    291
# VETE           1             295     44
#
#                                                                     abstract  \
#                                                            top freq    count
# subjectArea
# AGRI                                                 Nutrients   39      899
# ARTS         Nakhara: Journal of Environmental Design and P...   26      171
# BIOC         International Journal of Biological Macromolec...   37      934
# BUSI          International Journal of Supply Chain Management   23      280
# CENG               International Journal of Molecular Sciences   85      581
# CHEM                                                 Molecules   82      825
# COMP            ACM International Conference Proceeding Series   96      870
# DECI         2021 IEEE 8th International Conference on Indu...    6       17
# DENT                                           BMC Oral Health   20      233
# EART                                Frontiers in Earth Science   13      183
# ECON                                 Singapore Economic Review    8      104
# ENER                  International Journal of Hydrogen Energy   71      391
# ENGI                                       Engineering Journal  146      748
# ENVI                                               Chemosphere   41      529
# HEAL                                       Abdominal Radiology   11      119
# IMMU                                                  Vaccines   52      437
# MATE                                 Key Engineering Materials   61      678
# MATH         ECTI-CON 2018 - 15th International Conference ...   20      208
# MEDI            Journal of the Medical Association of Thailand  156     2839
# MULT                                                   Heliyon   65      264
# NEUR                                                     PeerJ   34      214
# NURS                                  Belitung Nursing Journal   18      115
# PHAR                   Thai Journal of Pharmaceutical Sciences   40      374
# PHYS                            Journal of High Energy Physics  192      508
# PSYC                                   Frontiers in Psychology   23      130
# SOCI                      Kasetsart Journal of Social Sciences   57      623
# VETE                       Thai Journal of Veterinary Medicine   92      295
#
#                                                                             \
#             unique                                                top freq
# subjectArea
# AGRI           899  pakistan botanical society rights reserved pen...    1
# ARTS           171    informa uk limited trading taylor francis gr...    1
# BIOC           934  © author(s 2017.taste perception influenced fa...    1
# BUSI           280  copyright   inderscience enterprises ltd. univ...    1
# CENG           581    elsevier b.v.a novel fibrous composite plate...    1
# CHEM           825    society innovative research rights reserved ...    1
# COMP           870    power system security assessment operational...    1
# DECI            17    elsevier b.v.tremendous data generated forms...    1
# DENT           233  springer verlag gmbh germany springer nature o...    1
# EART           183    institute oceanology polish academy sciences...    1
# ECON           104    inderscience enterprises ltd. paper investig...    1
# ENER           391    hydrogen energy publications llca solid oxid...    1
# ENGI           747  copyright   techno press ltd. paper presents a...    2
# ENVI           529    elsevier b.v.a pyrene degrading microbial co...    1
# HEAL           119  background hyperkyphosis frequently found nowa...    1
# IMMU           437    elsevier ltddead asp glu ala asp)-box polype...    1
# MATE           678  microstructure corrosion behavior hot rolled t...    1
# MATH           208    taylor francis group llc.in döbler stein met...    1
# MEDI          2839  natco rights reserved introduction population ...    1
# MULT           264  walailak university rights reserved thailand p...    1
# NEUR           214  springer science+business media new york zika ...    1
# NURS           115    american academy hospice palliative medicine...    1
# PHAR           374    elsevier b.v. dengue infection global burden...    1
# PHYS           508    elsevier ltdthree types ultrafine fully vulc...    1
# PSYC           130    elsevier ltdacross studies examined moderati...    1
# SOCI           623  kassel university press gmbh.this study aimed ...    1
# VETE           295    elsevier inc. past decade studies reproducti...    1
#
#             keywords         \
#                count unique
# subjectArea
# AGRI             899    897
# ARTS             171    171
# BIOC             934    933
# BUSI             280    279
# CENG             581    578
# CHEM             825    825
# COMP             870    868
# DECI              17     17
# DENT             233    233
# EART             183    182
# ECON             104    104
# ENER             391    390
# ENGI             748    747
# ENVI             529    529
# HEAL             119    119
# IMMU             437    437
# MATE             678    676
# MATH             208    206
# MEDI            2839   2834
# MULT             264    264
# NEUR             214    214
# NURS             115    115
# PHAR             374    374
# PHYS             508    421
# PSYC             130    130
# SOCI             623    622
# VETE             295    294
#
#                                                                      \
#                                                            top freq
# subjectArea
# AGRI         African swine fever virus Compound disinfectan...    2
# ARTS         Comparative law Employers’ liability Legal tra...    1
# BIOC         bioenergy biomolecule production biorefineries...    2
# BUSI                Green supply chain Sustainability Thailand    2
# CENG         epigenetics Ezh2 lipopolysaccharide macrophage...    2
# CHEM         Agriculture land management Conserved area Soi...    1
# COMP         machine learning Neural networks recommender s...    2
# DECI         Data stream clustering Elliptic-micro-cluster ...    1
# DENT         Cleft palate Pediatric dentistry Radiation dos...    1
# EART         active fault Mae Hong Son Basin Mae Hong Son F...    2
# ECON         BCS Business cycle synchronisation Business cy...    1
# ENER         aggregator battery energy storage system (BESS...    2
# ENGI         analytical model composite column compressive ...    2
# ENVI         Mangrove sediment Mycobacterium Novosphingobiu...    1
# HEAL                Cobb angle Dowager's hump Round back Spine    1
# IMMU         Antiviral response DDX41 DNA-sensing pathway S...    1
# MATE         Aluminum Interpenetrating phase composite Mech...    2
# MATH         Bisymmetric matrices Bisymmetric nonnegative i...    2
# MEDI         Alveolar bone grafting Alveolar ridge augmenta...    2
# MULT         Lee model code Pinch phase Plasma focus Plasma...    1
# NEUR         Autoimmunity Cytokines Guillain-Barre syndrome...    1
# NURS         chronic conditions end-of-life care intensity ...    1
# PHAR         Dengue Drug discovery Envelope Flavanone Flavi...    1
# PHYS         Beyond Standard Model Hadron-Hadron scattering...   15
# PSYC               Grandiose Narcissism Persistence Vulnerable    1
# SOCI         Equilibrium price Equilibrium quantity Natural...    2
# VETE                   Backfat Farrowing IgG Pig Prostaglandin    2
#
#             abstract_cleaned         \
#                        count unique
# subjectArea
# AGRI                     899    899
# ARTS                     171    171
# BIOC                     934    934
# BUSI                     280    280
# CENG                     581    581
# CHEM                     825    825
# COMP                     870    870
# DECI                      17     17
# DENT                     233    233
# EART                     183    183
# ECON                     104    104
# ENER                     391    391
# ENGI                     748    747
# ENVI                     529    529
# HEAL                     119    119
# IMMU                     437    437
# MATE                     678    678
# MATH                     208    208
# MEDI                    2839   2839
# MULT                     264    264
# NEUR                     214    214
# NURS                     115    115
# PHAR                     374    374
# PHYS                     508    508
# PSYC                     130    130
# SOCI                     623    623
# VETE                     295    295
#
#
#                                                            top freq
# subjectArea
# AGRI         pakistan botanical society rights reserved pen...    1
# ARTS           informa uk limited trading taylor francis gr...    1
# BIOC         © author(s 2017.taste perception influenced fa...    1
# BUSI         copyright   inderscience enterprises ltd. univ...    1
# CENG           elsevier b.v.a novel fibrous composite plate...    1
# CHEM           society innovative research rights reserved ...    1
# COMP           power system security assessment operational...    1
# DECI           elsevier b.v.tremendous data generated forms...    1
# DENT         springer verlag gmbh germany springer nature o...    1
# EART           institute oceanology polish academy sciences...    1
# ECON           inderscience enterprises ltd. paper investig...    1
# ENER           hydrogen energy publications llca solid oxid...    1
# ENGI         copyright   techno press ltd. paper presents a...    2
# ENVI           elsevier b.v.a pyrene degrading microbial co...    1
# HEAL         background hyperkyphosis frequently found nowa...    1
# IMMU           elsevier ltddead asp glu ala asp)-box polype...    1
# MATE         microstructure corrosion behavior hot rolled t...    1
# MATH           taylor francis group llc.in döbler stein met...    1
# MEDI         natco rights reserved introduction population ...    1
# MULT         walailak university rights reserved thailand p...    1
# NEUR         springer science+business media new york zika ...    1
# NURS           american academy hospice palliative medicine...    1
# PHAR           elsevier b.v. dengue infection global burden...    1
# PHYS           elsevier ltdthree types ultrafine fully vulc...    1
# PSYC           elsevier ltdacross studies examined moderati...    1
# SOCI         kassel university press gmbh.this study aimed ...    1
# VETE           elsevier inc. past decade studies reproducti...    1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.utils import compute_class_weight
from xgboost import XGBClassifier
from sklearn.metrics import classification_report

# Assuming you have a DataFrame 'df' with columns: title, publicationName, abstract, keywords, subjectArea

# Text preprocessing and vectorization
text_data = df['title'] + ' ' + df['publicationName'] + ' ' + df['abstract'] + ' ' + df['keywords']
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(text_data)
y = df['subjectArea']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_encoded

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Create and train XGBoost model
model = XGBClassifier()
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       184
#            1       0.83      0.48      0.61        31
#            2       0.54      0.44      0.48       201
#            3       0.62      0.47      0.53        49
#            4       0.79      0.63      0.70       125
#            5       0.60      0.81      0.69       144
#            6       0.78      0.85      0.81       185
#            7       0.00      0.00      0.00         1
#            8       0.79      0.66      0.72        50
#            9       0.82      0.50      0.62        28
#           10       0.69      0.42      0.52        26
#           11       0.63      0.60      0.62        73
#           12       0.59      0.58      0.58       149
#           13       0.61      0.60      0.61       112
#           14       0.57      0.20      0.30        20
#           15       0.71      0.52      0.60        90
#           16       0.67      0.67      0.67       145
#           17       0.85      0.57      0.69        40
#           18       0.69      0.89      0.78       539
#           19       0.98      0.77      0.86        57
#           20       0.90      0.59      0.71        44
#           21       0.78      0.56      0.65        25
#           22       0.83      0.60      0.70        88
#           23       0.90      0.74      0.81       110
#           24       0.82      0.47      0.60        19
#           25       0.55      0.60      0.57       114
#           26       0.80      0.91      0.85        65
#
#     accuracy                           0.69      2714
#    macro avg       0.70      0.59      0.63      2714
# weighted avg       0.70      0.69      0.68      2714

# %%
# Decode numeric predictions back to original labels
y_pred_labels = le.inverse_transform(y_pred)

# Example: Print the first 10 decoded predictions
print(y_pred_labels[:10])
